# %% [markdown]
# ## Детекция клеток

# %% [markdown]
# Ваша задача: обучить YOLO для детекции дрожжевых клеток и микроструктур (см. [07_object_detection.ipynb](../workshops/07_object_detection.ipynb)). Всё необходимое для запуска обучения вы можете взять из ноутбука с практикой, доделать нужно будет самую малость:
# - реализовать расчёт Mean Average Precision для всего валидационного сета
# - попробовать привести regression loss к виду, который используется в Yolo9000 и YoloV3
# - подобрать лучшие размеры якорных рамок с помощью кластеризации
#
# Основная цель: любыми средствами добиться $mAP > 0.6$ на валидации.
#
# Используйте класс `torchmetrics.detection.MeanAveragePrecision` для расчёта $mAP$.
#
# Нас будет интересовать именно значение `map` в словаре со всеми метриками - это mean average precision, усреднённый по всем отсечкам intersection over union в диапазоне $[0.5, 0.95]$ (см. документацию к классу).
#
# При решении можно пользоваться `lightning` или писать цикл обучения вручную. В последнем случае не забудьте вручную отправить модель и батчи на GPU, чтобы обучалось быстрее

# %%
 ! wget https://tudatalib.ulb.tu-darmstadt.de/bitstream/handle/tudatalib/3799/yeast_cell_in_microstructures_dataset.zip
 ! unzip yeast_cell_in_microstructures_dataset.zip -d yeast_cell_in_microstructures_dataset
# Out:
# --2024-10-28 20:05:56--  https://tudatalib.ulb.tu-darmstadt.de/bitstream/handle/tudatalib/3799/yeast_cell_in_microstructures_dataset.zip
# Resolving tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)... 130.83.152.157
# Connecting to tudatalib.ulb.tu-darmstadt.de (tudatalib.ulb.tu-darmstadt.de)|130.83.152.157|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: unspecified [application/zip]
# Saving to: ‘yeast_cell_in_microstructures_dataset.zip’
#
#      0K .......... .......... .......... .......... ..........  572K
#     50K .......... .......... .......... .......... .......... 1.07M
#    100K .......... .......... .......... .......... .......... 65.4M
#    150K .......... .......... .......... .......... .......... 1.07M
#    200K .......... .......... .......... .......... ..........  199M
#    250K .......... .......... .......... .......... .......... 86.0M
#    300K .......... .......... .......... .......... .......... 95.1M
#    350K .......... .......... .......... .......... .......... 1.10M
#    400K .......... .......... .......... .......... ..........  139M
#    450K .......... .......... .......... .......... ..........  124M
#    500K .......... .......... .......... .......... ..........  170M
#    550K .......... .......... .......... .......... ..........  121M
#    600K .......... .......... .......... .......... .......... 99.3M
#    650K .......... .......... .......... .......... ..........  101M
#    700K .......... .......... .......... .......... ..........  168M
#    750K .......... .......... .......... .......... .......... 89.4M
#    800K .......... .......... .......... .......... .......... 1.14M
#    850K .......... .......... .......... .......... ..........  128M
#    900K .......... .......... .......... .......... ..........  175M
#    950K .......... .......... .......... .......... ..........  130M
#   1000K .......... .......... .......... .......... ..........  116M
#   1050K .......... .......... .......... .......... ..........  162M
#   1100K .......... .......... .......... .......... ..........  112M
#   1150K .......... .......... .......... .......... .......... 88.4M
#   1200K .......... .......... .......... .......... ..........  132M
#   1250K .......... .......... .......... .......... .......... 87.8M
#   1300K .......... .......... .......... .......... .......... 79.4M
#   1350K .......... .......... .......... .......... ..........  175M
#   1400K .......... .......... .......... .......... ..........  141M
#   1450K .......... .......... .......... .......... .......... 85.8M
#   1500K .......... .......... .......... .......... .......... 51.8M
#   1550K .......... .......... .......... .......... ..........  174M
#   1600K .......... .......... .......... .......... ..........  192M
#   1650K .......... .......... .......... .......... .......... 1.25M
#   1700K .......... .......... .......... .......... ..........  172M
#   1750K .......... .......... .......... .......... ..........  191M
#   1800K .......... .......... .......... .......... .......... 70.6M
#   1850K .......... .......... .......... .......... ..........  139M
#   1900K .......... .......... .......... .......... ..........  226M
#   1950K .......... .......... .......... .......... .......... 65.5M
#   2000K .......... .......... .......... .......... ..........  136M
#   2050K .......... .......... .......... .......... ..........  153M
#   2100K .......... .......... .......... .......... ..........  136M
#   2150K .......... .......... .......... .......... .......... 79.9M
#   2200K .......... .......... .......... .......... ..........  166M
#   2250K .......... .......... .......... .......... ..........  109M
#   2300K .......... .......... .......... .......... ..........  107M
#   2350K .......... .......... .......... .......... .......... 80.1M
#   2400K .......... .......... .......... .......... ..........  130M
#   2450K .......... .......... .......... .......... .......... 74.6M
#   2500K .......... .......... .......... .......... ..........  163M
#   2550K .......... .......... .......... .......... ..........  117M
#   2600K .......... .......... .......... .......... ..........  139M
#   2650K .......... .......... .......... .......... ..........  143M
#   2700K .......... .......... .......... .......... ..........  118M
#   2750K .......... .......... .......... .......... .......... 85.3M
#   2800K .......... .......... .......... .......... ..........  143M
#   2850K .......... .......... .......... .......... ..........  113M
#   2900K .......... .......... .......... .......... ..........  141M
#   2950K .......... .......... .......... .......... .......... 64.0M
#   3000K .......... .......... .......... .......... ..........  188M
#   3050K .......... .......... .......... .......... ..........  137M
#   3100K .......... .......... .......... .......... ..........  139M
#   3150K .......... .......... .......... .......... .......... 82.9M
#   3200K .......... .......... .......... .......... ..........  123M
#   3250K .......... .......... .......... .......... ..........  127M
#   3300K .......... .......... .......... .......... .......... 1.53M
#   3350K .......... .......... .......... .......... ..........  136M
#   3400K .......... .......... .......... .......... ..........  178M
#   3450K .......... .......... .......... .......... .......... 76.8M
#   3500K .......... .......... .......... .......... ..........  142M
#   3550K .......... .......... .......... .......... ..........  125M
#   3600K .......... .......... .......... .......... ..........  133M
#   3650K .......... .......... .......... .......... ..........  122M
#   3700K .......... .......... .......... .......... ..........  100M
#   3750K .......... .......... .......... .......... ..........  101M
#   3800K .......... .......... .......... .......... .......... 99.1M
#   3850K .......... .......... .......... .......... ..........  151M
#   3900K .......... .......... .......... .......... ..........  126M
#   3950K .......... .......... .......... .......... .......... 72.8M
#   4000K .......... .......... .......... .......... ..........  174M
#   4050K .......... .......... .......... .......... .......... 99.0M
#   4100K .......... .......... .......... .......... ..........  130M
#   4150K .......... .......... .......... .......... .......... 71.8M
#   4200K .......... .......... .......... .......... ..........  215M
#   4250K .......... .......... .......... .......... ..........  144M
#   4300K .......... .......... .......... .......... ..........  139M
#   4350K .......... .......... .......... .......... .......... 72.9M
#   4400K .......... .......... .......... .......... ..........  136M
#   4450K .......... .......... .......... .......... ..........  120M
#   4500K .......... .......... .......... .......... ..........  129M
#   4550K .......... .......... .......... .......... .......... 89.0M
#   4600K .......... .......... .......... .......... ..........  113M
#   4650K .......... .......... .......... .......... ..........  121M
#   4700K .......... .......... .......... .......... .......... 83.8M
#   4750K .......... .......... .......... .......... .......... 50.9M
#   4800K .......... .......... .......... .......... ..........  192M
#   4850K .......... .......... .......... .......... ..........  180M
#   4900K .......... .......... .......... .......... ..........  160M
#   4950K .......... .......... .......... .......... ..........  102M
#   5000K .......... .......... .......... .......... ..........  211M
#   5050K .......... .......... .......... .......... .......... 89.3M
#   5100K .......... .......... .......... .......... ..........  167M
#   5150K .......... .......... .......... .......... .......... 72.2M
#   5200K .......... .......... .......... .......... ..........  127M
#   5250K .......... .......... .......... .......... ..........  153M
#   5300K .......... .......... .......... .......... .......... 73.4M
#   5350K .......... .......... .......... .......... ..........  165M
#   5400K .......... .......... .......... .......... ..........  152M
#   5450K .......... .......... .......... .......... ..........  125M
#   5500K .......... .......... .......... .......... .......... 67.6M
#   5550K .......... .......... .......... .......... ..........  136M
#   5600K .......... .......... .......... .......... ..........  151M
#   5650K .......... .......... .......... .......... ..........  103M
#   5700K .......... .......... .......... .......... .......... 98.7M
#   5750K .......... .......... .......... .......... ..........  107M
#   5800K .......... .......... .......... .......... ..........  165M
#   5850K .......... .......... .......... .......... ..........  126M
#   5900K .......... .......... .......... .......... ..........  103M
#   5950K .......... .......... .......... .......... ..........  101M
#   6000K .......... .......... .......... .......... .......... 60.1M
#   6050K .......... .......... .......... .......... ..........  189M
#   6100K .......... .......... .......... .......... ..........  155M
#   6150K .......... .......... .......... .......... ..........  128M
#   6200K .......... .......... .......... .......... .......... 99.4M
#   6250K .......... .......... .......... .......... ..........  158M
#   6300K .......... .......... .......... .......... .......... 96.9M
#   6350K .......... .......... .......... .......... .......... 2.48M
#   6400K .......... .......... .......... .......... .......... 79.6M
#   6450K .......... .......... .......... .......... .......... 16.1M
#   6500K .......... .......... .......... .......... ..........  102M
#   6550K .......... .......... .......... .......... .......... 90.1M
#   6600K .......... .......... .......... .......... ..........  145M
#   6650K .......... .......... .......... .......... .......... 98.6M
#   6700K .......... .......... .......... .......... ..........  102M
#   6750K .......... .......... .......... .......... .......... 73.4M
#   6800K .......... .......... .......... .......... ..........  119M
#   6850K .......... .......... .......... .......... ..........  206M
#   6900K .......... .......... .......... .......... ..........  103M
#   6950K .......... .......... .......... .......... .......... 85.2M
#   7000K .......... .......... .......... .......... ..........  131M
#   7050K .......... .......... .......... .......... ..........  112M
#   7100K .......... .......... .......... .......... ..........  160M
#   7150K .......... .......... .......... .......... .......... 91.4M
#   7200K .......... .......... .......... .......... ..........  135M
#   7250K .......... .......... .......... .......... ..........  102M
#   7300K .......... .......... .......... .......... .......... 81.6M
#   7350K .......... .......... .......... .......... .......... 67.5M
#   7400K .......... .......... .......... .......... ..........  166M
#   7450K .......... .......... .......... .......... ..........  169M
#   7500K .......... .......... .......... .......... ..........  134M
#   7550K .......... .......... .......... .......... .......... 72.2M
#   7600K .......... .......... .......... .......... ..........  155M
#   7650K .......... .......... .......... .......... ..........  138M
#   7700K .......... .......... .......... .......... ..........  104M
#   7750K .......... .......... .......... .......... ..........  129M
#   7800K .......... .......... .......... .......... .......... 89.6M
#   7850K .......... .......... .......... .......... ..........  119M
#   7900K .......... .......... .......... .......... ..........  119M
#   7950K .......... .......... .......... .......... .......... 87.1M
#   8000K .......... .......... .......... .......... ..........  115M
#   8050K .......... .......... .......... .......... ..........  108M
#   8100K .......... .......... .......... .......... ..........  122M
#   8150K .......... .......... .......... .......... .......... 86.9M
#   8200K .......... .......... .......... .......... .......... 93.1M
#   8250K .......... .......... .......... .......... ..........  141M
#   8300K .......... .......... .......... .......... ..........  165M
#   8350K .......... .......... .......... .......... ..........  130M
#   8400K .......... .......... .......... .......... .......... 95.9M
#   8450K .......... .......... .......... .......... ..........  114M
#   8500K .......... .......... .......... .......... ..........  104M
#   8550K .......... .......... .......... .......... .......... 61.8M
#   8600K .......... .......... .......... .......... ..........  177M
#   8650K .......... .......... .......... .......... ..........  169M
#   8700K .......... .......... .......... .......... ..........  138M
#   8750K .......... .......... .......... .......... ..........  108M
#   8800K .......... .......... .......... .......... ..........  118M
#   8850K .......... .......... .......... .......... .......... 99.6M
#   8900K .......... .......... .......... .......... ..........  116M
#   8950K .......... .......... .......... .......... ..........  131M
#   9000K .......... .......... .......... .......... .......... 98.7M
#   9050K .......... .......... .......... .......... ..........  101M
#   9100K .......... .......... .......... .......... ..........  111M
#   9150K .......... .......... .......... .......... ..........  139M
#   9200K .......... .......... .......... .......... .......... 99.1M
#   9250K .......... .......... .......... .......... ..........  116M
#   9300K .......... .......... .......... .......... .......... 96.8M
#   9350K .......... .......... .......... .......... ..........  165M
#   9400K .......... .......... .......... .......... .......... 2.92M
#   9450K .......... .......... .......... .......... ..........  122M
#   9500K .......... .......... .......... .......... .......... 20.7M
#   9550K .......... .......... .......... .......... .......... 33.7M
#   9600K .......... .......... .......... .......... .......... 64.4M
#   9650K .......... .......... .......... .......... ..........  151M
#   9700K .......... .......... .......... .......... .......... 91.0M
#   9750K .......... .......... .......... .......... ..........  148M
#   9800K .......... .......... .......... .......... ..........  109M
#   9850K .......... .......... .......... .......... .......... 92.1M
#   9900K .......... .......... .......... .......... ..........  121M
#   9950K .......... .......... .......... .......... .......... 93.3M
#  10000K .......... .......... .......... .......... ..........  124M
#  10050K .......... .......... .......... .......... ..........  119M
#  10100K .......... .......... .......... .......... .......... 93.5M
#  10150K .......... .......... .......... .......... ..........  121M
#  10200K .......... .......... .......... .......... ..........  151M
#  10250K .......... .......... .......... .......... .......... 1.55M
#  10300K .......... .......... .......... .......... ..........  134M
#  10350K .......... .......... .......... .......... ..........  108M
#  10400K .......... .......... .......... .......... ..........  150M
#  10450K .......... .......... .......... .......... ..........  135M
#  10500K .......... .......... .......... .......... ..........  135M
#  10550K .......... .......... .......... .......... .......... 80.8M
#  10600K .......... .......... .......... .......... ..........  158M
#  10650K .......... .......... .......... .......... ..........  140M
#  10700K .......... .......... .......... .......... .......... 82.6M
#  10750K .......... .......... .......... .......... ..........  131M
#  10800K .......... .......... .......... .......... ..........  136M
#  10850K .......... .......... .......... .......... .......... 89.8M
#  10900K .......... .......... .......... .......... ..........  170M
#  10950K .......... .......... .......... .......... .......... 44.0M
#  11000K .......... .......... .......... .......... ..........  148M
#  11050K .......... .......... .......... .......... ..........  148M
#  11100K .......... .......... .......... .......... ..........  142M
#  11150K .......... .......... .......... .......... ..........  129M
#  11200K .......... .......... .......... .......... ..........  149M
#  11250K .......... .......... .......... .......... ..........  119M
#  11300K .......... .......... .......... .......... .......... 88.3M
#  11350K .......... .......... .......... .......... .......... 98.9M
#  11400K .......... .......... .......... .......... ..........  141M
#  11450K .......... .......... .......... .......... .......... 89.2M
#  11500K .......... .......... .......... .......... ..........  145M
#  11550K .......... .......... .......... .......... ..........  140M
#  11600K .......... .......... .......... .......... ..........  140M
#  11650K .......... .......... .......... .......... .......... 92.5M
#  11700K .......... .......... .......... .......... ..........  122M
#  11750K .......... .......... .......... .......... ..........  124M
#  11800K .......... .......... .......... .......... ..........  113M
#  11850K .......... .......... .......... .......... ..........  110M
#  11900K .......... .......... .......... .......... ..........  103M
#  11950K .......... .......... .......... .......... .......... 63.6M
#  12000K .......... .......... .......... .......... ..........  144M
#  12050K .......... .......... .......... .......... ..........  145M
#  12100K .......... .......... .......... .......... ..........  134M
#  12150K .......... .......... .......... .......... ..........  160M
#  12200K .......... .......... .......... .......... .......... 68.3M
#  12250K .......... .......... .......... .......... ..........  182M
#  12300K .......... .......... .......... .......... ..........  118M
#  12350K .......... .......... .......... .......... .......... 98.4M
#  12400K .......... .......... .......... .......... ..........  120M
#  12450K .......... .......... .......... .......... ..........  129M
#  12500K .......... .......... .......... .......... ..........  110M
#  12550K .......... .......... .......... .......... ..........  102M
#  12600K .......... .......... .......... .......... ..........  134M
#  12650K .......... .......... .......... .......... .......... 90.4M
#  12700K .......... .......... .......... .......... ..........  156M
#  12750K .......... .......... .......... .......... ..........  108M
#  12800K .......... .......... .......... .......... .......... 77.9M
#  12850K .......... .......... .......... .......... .......... 87.2M
#  12900K .......... .......... .......... .......... ..........  172M
#  12950K .......... .......... .......... .......... ..........  114M
#  13000K .......... .......... .......... .......... ..........  157M
#  13050K .......... .......... .......... .......... ..........  116M
#  13100K .......... .......... .......... .......... ..........  111M
#  13150K .......... .......... .......... .......... .......... 95.6M
#  13200K .......... .......... .......... .......... ..........  107M
#  13250K .......... .......... .......... .......... .......... 2.44M
#  13300K .......... .......... .......... .......... .......... 66.6M
#  13350K .......... .......... .......... .......... ..........  107M
#  13400K .......... .......... .......... .......... ..........  113M
#  13450K .......... .......... .......... .......... .......... 97.5M
#  13500K .......... .......... .......... .......... .......... 89.0M
#  13550K .......... .......... .......... .......... ..........  124M
#  13600K .......... .......... .......... .......... .......... 15.1M
#  13650K .......... .......... .......... .......... .......... 97.9M
#  13700K .......... .......... .......... .......... .......... 98.3M
#  13750K .......... .......... .......... .......... .......... 77.1M
#  13800K .......... .......... .......... .......... ..........  143M
#  13850K .......... .......... .......... .......... ..........  185M
#  13900K .......... .......... .......... .......... .......... 94.6M
#  13950K .......... .......... .......... .......... .......... 81.0M
#  14000K .......... .......... .......... .......... ..........  151M
#  14050K .......... .......... .......... .......... ..........  125M
#  14100K .......... .......... .......... .......... .......... 89.0M
#  14150K .......... .......... .......... .......... ..........  171M
#  14200K .......... .......... .......... .......... .......... 99.7M
#  14250K .......... .......... .......... .......... ..........  117M
#  14300K .......... .......... .......... .......... ..........  107M
#  14350K .......... .......... .......... .......... .......... 93.1M
#  14400K .......... .......... .......... .......... ..........  129M
#  14450K .......... .......... .......... .......... ..........  116M
#  14500K .......... .......... .......... .......... ..........  125M
#  14550K .......... .......... .......... .......... .......... 99.7M
#  14600K .......... .......... .......... .......... ..........  106M
#  14650K .......... .......... .......... .......... .......... 92.3M
#  14700K .......... .......... .......... .......... ..........  179M
#  14750K .......... .......... .......... .......... .......... 90.8M
#  14800K .......... .......... .......... .......... ..........  108M
#  14850K .......... .......... .......... .......... ..........  126M
#  14900K .......... .......... .......... .......... .......... 82.8M
#  14950K .......... .......... .......... .......... ..........  106M
#  15000K .......... .......... .......... .......... ..........  193M
#  15050K .......... .......... .......... .......... ..........  103M
#  15100K .......... .......... .......... .......... ..........  114M
#  15150K .......... .......... .......... .......... ..........  113M
#  15200K .......... .......... .......... .......... ..........  107M
#  15250K .......... .......... .......... .......... .......... 99.8M
#  15300K .......... .......... .......... .......... ..........  108M
#  15350K .......... .......... .......... .......... ..........  107M
#  15400K .......... .......... .......... .......... ..........  140M
#  15450K .......... .......... .......... .......... ..........  108M
#  15500K .......... .......... .......... .......... ..........  102M
#  15550K .......... .......... .......... .......... ..........  117M
#  15600K .......... .......... .......... .......... ..........  101M
#  15650K .......... .......... .......... .......... .......... 91.2M
#  15700K .......... .......... .......... .......... ..........  154M
#  15750K .......... .......... .......... .......... ..........  106M
#  15800K .......... .......... .......... .......... ..........  138M
#  15850K .......... .......... .......... .......... .......... 82.5M
#  15900K .......... .......... .......... .......... ..........  143M
#  15950K .......... .......... .......... .......... ..........  128M
#  16000K .......... .......... .......... .......... .......... 91.2M
#  16050K .......... .......... .......... .......... ..........  101M
#  16100K .......... .......... .......... .......... .......... 40.3M
#  16150K .......... .......... .......... .......... .......... 97.9M
#  16200K .......... .......... .......... .......... ..........  131M
#  16250K .......... .......... .......... .......... .......... 3.14M
#  16300K .......... .......... .......... .......... ..........  128M
#  16350K .......... .......... .......... .......... .......... 61.2M
#  16400K .......... .......... .......... .......... ..........  141M
#  16450K .......... .......... .......... .......... ..........  102M
#  16500K .......... .......... .......... .......... .......... 71.2M
#  16550K .......... .......... .......... .......... .......... 78.0M
#  16600K .......... .......... .......... .......... .......... 17.5M
#  16650K .......... .......... .......... .......... .......... 75.1M
#  16700K .......... .......... .......... .......... ..........  120M
#  16750K .......... .......... .......... .......... .......... 81.8M
#  16800K .......... .......... .......... .......... ..........  137M
#  16850K .......... .......... .......... .......... .......... 99.6M
#  16900K .......... .......... .......... .......... ..........  137M
#  16950K .......... .......... .......... .......... .......... 99.7M
#  17000K .......... .......... .......... .......... .......... 51.0M
#  17050K .......... .......... .......... .......... .......... 86.2M
#  17100K .......... .......... .......... .......... ..........  119M
#  17150K .......... .......... .......... .......... ..........  117M
#  17200K .......... .......... .......... .......... .......... 89.5M
#  17250K .......... .......... .......... .......... ..........  182M
#  17300K .......... .......... .......... .......... .......... 18.0M
#  17350K .......... .......... .......... .......... ..........  155M
#  17400K .......... .......... .......... .......... .......... 72.5M
#  17450K .......... .......... .......... .......... ..........  132M
#  17500K .......... .......... .......... .......... .......... 88.6M
#  17550K .......... .......... .......... .......... ..........  140M
#  17600K .......... .......... .......... .......... ..........  107M
#  17650K .......... .......... .......... .......... .......... 93.4M
#  17700K .......... .......... .......... .......... ..........  132M
#  17750K .......... .......... .......... .......... ..........  113M
#  17800K .......... .......... .......... .......... ..........  158M
#  17850K .......... .......... .......... .......... ..........  107M
#  17900K .......... .......... .......... .......... .......... 77.7M
#  17950K .......... .......... .......... .......... .......... 82.9M
#  18000K .......... .......... .......... .......... ..........  140M
#  18050K .......... .......... .......... .......... ..........  188M
#  18100K .......... .......... .......... .......... .......... 66.6M
#  18150K .......... .......... .......... .......... ..........  182M
#  18200K .......... .......... .......... .......... ..........  106M
#  18250K .......... .......... .......... .......... ..........  165M
#  18300K .......... .......... .......... .......... .......... 83.2M
#  18350K .......... .......... .......... .......... ..........  162M
#  18400K .......... .......... .......... .......... .......... 90.8M
#  18450K .......... .......... .......... .......... ..........  116M
#  18500K .......... .......... .......... .......... ..........  151M
#  18550K .......... .......... .......... .......... .......... 92.9M
#  18600K .......... .......... .......... .......... .......... 85.6M
#  18650K .......... .......... .......... .......... ..........  172M
#  18700K .......... .......... .......... .......... ..........  105M
#  18750K .......... .......... .......... .......... ..........  119M
#  18800K .......... .......... .......... .......... .......... 86.7M
#  18850K .......... .......... .......... .......... ..........  137M
#  18900K .......... .......... .......... .......... ..........  102M
#  18950K .......... .......... .......... .......... ..........  154M
#  19000K .......... .......... .......... .......... ..........  111M
#  19050K .......... .......... .......... .......... ..........  123M
#  19100K .......... .......... .......... .......... .......... 48.0M
#  19150K .......... .......... .......... .......... ..........  182M
#  19200K .......... .......... .......... .......... ..........  176M
#  19250K .......... .......... .......... .......... .......... 3.64M
#  19300K .......... .......... .......... .......... .......... 7.54M
#  19350K .......... .......... .......... .......... .......... 93.7M
#  19400K .......... .......... .......... .......... ..........  194M
#  19450K .......... .......... .......... .......... .......... 62.6M
#  19500K .......... .......... .......... .......... ..........  163M
#  19550K .......... .......... .......... .......... ..........  118M
#  19600K .......... .......... .......... .......... ..........  142M
#  19650K .......... .......... .......... .......... ..........  107M
#  19700K .......... .......... .......... .......... .......... 95.8M
#  19750K .......... .......... .......... .......... ..........  144M
#  19800K .......... .......... .......... .......... .......... 85.5M
#  19850K .......... .......... .......... .......... ..........  134M
#  19900K .......... .......... .......... .......... ..........  111M
#  19950K .......... .......... .......... .......... ..........  100M
#  20000K .......... .......... .......... .......... ..........  120M
#  20050K .......... .......... .......... .......... ..........  167M
#  20100K .......... .......... .......... .......... .......... 91.7M
#  20150K .......... .......... .......... .......... ..........  111M
#  20200K .......... .......... .......... .......... ..........  112M
#  20250K .......... .......... .......... .......... ..........  139M
#  20300K .......... .......... .......... .......... .......... 82.5M
#  20350K .......... .......... .......... .......... ..........  117M
#  20400K .......... .......... .......... .......... ..........  127M
#  20450K .......... .......... .......... .......... .......... 63.7M
#  20500K .......... .......... .......... .......... .......... 74.8M
#  20550K .......... .......... .......... .......... ..........  102M
#  20600K .......... .......... .......... .......... .......... 81.7M
#  20650K .......... .......... .......... .......... ..........  172M
#  20700K .......... .......... .......... .......... .......... 92.1M
#  20750K .......... .......... .......... .......... ..........  137M
#  20800K .......... .......... .......... .......... ..........  121M
#  20850K .......... .......... .......... .......... .......... 90.3M
#  20900K .......... .......... .......... .......... ..........  116M
#  20950K .......... .......... .......... .......... .......... 97.2M
#  21000K .......... .......... .......... .......... .......... 96.9M
#  21050K .......... .......... .......... .......... ..........  162M
#  21100K .......... .......... .......... .......... .......... 15.1M
#  21150K .......... .......... .......... .......... ..........  163M
#  21200K .......... .......... .......... .......... ..........  200M
#  21250K .......... .......... .......... .......... ..........  119M
#  21300K .......... .......... .......... .......... ..........  113M
#  21350K .......... .......... .......... .......... ..........  126M
#  21400K .......... .......... .......... .......... .......... 93.9M
#  21450K .......... .......... .......... .......... .......... 98.3M
#  21500K .......... .......... .......... .......... ..........  120M
#  21550K .......... .......... .......... .......... .......... 81.8M
#  21600K .......... .......... .......... .......... ..........  161M
#  21650K .......... .......... .......... .......... ..........  161M
#  21700K .......... .......... .......... .......... .......... 90.0M
#  21750K .......... .......... .......... .......... ..........  113M
#  21800K .......... .......... .......... .......... .......... 51.6M
#  21850K .......... .......... .......... .......... ..........  182M
#  21900K .......... .......... .......... .......... ..........  137M
#  21950K .......... .......... .......... .......... ..........  153M
#  22000K .......... .......... .......... .......... ..........  122M
#  22050K .......... .......... .......... .......... ..........  113M
#  22100K .......... .......... .......... .......... ..........  121M
#  22150K .......... .......... .......... .......... .......... 94.2M
#  22200K .......... .......... .......... .......... .......... 4.61M
#  22250K .......... .......... .......... .......... ..........  124M
#  22300K .......... .......... .......... .......... .......... 59.4M
#  22350K .......... .......... .......... .......... .......... 8.42M
#  22400K .......... .......... .......... .......... .......... 50.9M
#  22450K .......... .......... .......... .......... .......... 73.5M
#  22500K .......... .......... .......... .......... .......... 90.9M
#  22550K .......... .......... .......... .......... ..........  157M
#  22600K .......... .......... .......... .......... ..........  101M
#  22650K .......... .......... .......... .......... ..........  130M
#  22700K .......... .......... .......... .......... .......... 81.0M
#  22750K .......... .......... .......... .......... ..........  102M
#  22800K .......... .......... .......... .......... .......... 80.5M
#  22850K .......... .......... .......... .......... ..........  210M
#  22900K .......... .......... .......... .......... .......... 99.3M
#  22950K .......... .......... .......... .......... .......... 81.4M
#  23000K .......... .......... .......... .......... ..........  150M
#  23050K .......... .......... .......... .......... ..........  118M
#  23100K .......... .......... .......... .......... .......... 86.6M
#  23150K .......... .......... .......... .......... .......... 17.6M
#  23200K .......... .......... .......... .......... .......... 82.2M
#  23250K .......... .......... .......... .......... ..........  155M
#  23300K .......... .......... .......... .......... .......... 91.3M
#  23350K .......... .......... .......... .......... .......... 87.7M
#  23400K .......... .......... .......... .......... ..........  103M
#  23450K .......... .......... .......... .......... .......... 72.7M
#  23500K .......... .......... .......... .......... ..........  143M
#  23550K .......... .......... .......... .......... ..........  147M
#  23600K .......... .......... .......... .......... .......... 62.8M
#  23650K .......... .......... .......... .......... ..........  146M
#  23700K .......... .......... .......... .......... ..........  132M
#  23750K .......... .......... .......... .......... ..........  184M
#  23800K .......... .......... .......... .......... ..........  161M
#  23850K .......... .......... .......... .......... ..........  162M
#  23900K .......... .......... .......... .......... ..........  108M
#  23950K .......... .......... .......... .......... ..........  124M
#  24000K .......... .......... .......... .......... .......... 69.0M
#  24050K .......... .......... .......... .......... ..........  174M
#  24100K .......... .......... .......... .......... ..........  123M
#  24150K .......... .......... .......... .......... .......... 92.0M
#  24200K .......... .......... .......... .......... .......... 29.2M
#  24250K .......... .......... .......... .......... ..........  183M
#  24300K .......... .......... .......... .......... .......... 95.7M
#  24350K .......... .......... .......... .......... .......... 82.9M
#  24400K .......... .......... .......... .......... ..........  192M
#  24450K .......... .......... .......... .......... ..........  167M
#  24500K .......... .......... .......... .......... ..........  104M
#  24550K .......... .......... .......... .......... ..........  101M
#  24600K .......... .......... .......... .......... ..........  137M
#  24650K .......... .......... .......... .......... .......... 75.2M
#  24700K .......... .......... .......... .......... ..........  150M
#  24750K .......... .......... .......... .......... ..........  132M
#  24800K .......... .......... .......... .......... .......... 85.0M
#  24850K .......... .......... .......... .......... ..........  152M
#  24900K .......... .......... .......... .......... ..........  108M
#  24950K .......... .......... .......... .......... .......... 94.1M
#  25000K .......... .......... .......... .......... .......... 86.4M
#  25050K .......... .......... .......... .......... ..........  134M
#  25100K .......... .......... .......... .......... .......... 2.62M
#  25150K .......... .......... .......... .......... ..........  191M
#  25200K .......... .......... .......... .......... ..........  124M
#  25250K .......... .......... .......... .......... .......... 86.0M
#  25300K .......... .......... .......... .......... .......... 64.8M
#  25350K .......... .......... .......... .......... ..........  190M
#  25400K .......... .......... .......... .......... ..........  109M
#  25450K .......... .......... .......... .......... ..........  106M
#  25500K .......... .......... .......... .......... ..........  158M
#  25550K .......... .......... .......... .......... ..........  145M
#  25600K .......... .......... .......... .......... ..........  105M
#  25650K .......... .......... .......... .......... ..........  102M
#  25700K .......... .......... .......... .......... ..........  149M
#  25750K .......... .......... .......... .......... .......... 89.6M
#  25800K .......... .......... .......... .......... ..........  157M
#  25850K .......... .......... .......... .......... ..........  121M
#  25900K .......... .......... .......... .......... .......... 84.1M
#  25950K .......... .......... .......... .......... .......... 79.3M
#  26000K .......... .......... .......... .......... ..........  194M
#  26050K .......... .......... .......... .......... .......... 69.1M
#  26100K .......... .......... .......... .......... ..........  120M
#  26150K .......... .......... .......... .......... ..........  149M
#  26200K .......... .......... .......... .......... .......... 73.9M
#  26250K .......... .......... .......... .......... .......... 56.0M
#  26300K .......... .......... .......... .......... .......... 53.8M
#  26350K .......... .......... .......... .......... .......... 99.6M
#  26400K .......... .......... .......... .......... ..........  107M
#  26450K .......... .......... .......... .......... ..........  117M
#  26500K .......... .......... .......... .......... ..........  107M
#  26550K .......... .......... .......... .......... ..........  101M
#  26600K .......... .......... .......... .......... ..........  119M
#  26650K .......... .......... .......... .......... ..........  119M
#  26700K .......... .......... .......... .......... .......... 95.7M
#  26750K .......... .......... .......... .......... .......... 98.2M
#  26800K .......... .......... .......... .......... ..........  166M
#  26850K .......... .......... .......... .......... .......... 1.56M
#  26900K .......... .......... .......... .......... ..........  147M
#  26950K .......... .......... .......... .......... ..........  169M
#  27000K .......... .......... .......... .......... ..........  160M
#  27050K .......... .......... .......... .......... ..........  123M
#  27100K .......... .......... .......... .......... .......... 73.2M
#  27150K .......... .......... .......... .......... ..........  184M
#  27200K .......... .......... .......... .......... ..........  124M
#  27250K .......... .......... .......... .......... ..........  111M
#  27300K .......... .......... .......... .......... .......... 93.7M
#  27350K .......... .......... .......... .......... ..........  107M
#  27400K .......... .......... .......... .......... ..........  147M
#  27450K .......... .......... .......... .......... ..........  108M
#  27500K .......... .......... .......... .......... .......... 85.1M
#  27550K .......... .......... .......... .......... ..........  104M
#  27600K .......... .......... .......... .......... ..........  129M
#  27650K .......... .......... .......... .......... ..........  124M
#  27700K .......... .......... .......... .......... ..........  114M
#  27750K .......... .......... .......... .......... .......... 93.4M
#  27800K .......... .......... .......... .......... ..........  149M
#  27850K .......... .......... .......... .......... ..........  107M
#  27900K .......... .......... .......... .......... .......... 92.7M
#  27950K .......... .......... .......... .......... ..........  135M
#  28000K .......... .......... .......... .......... .......... 95.5M
#  28050K .......... .......... .......... .......... ..........  144M
#  28100K .......... .......... .......... .......... .......... 93.8M
#  28150K .......... .......... .......... .......... .......... 99.9M
#  28200K .......... .......... .......... .......... ..........  161M
#  28250K .......... .......... .......... .......... .......... 97.4M
#  28300K .......... .......... .......... .......... ..........  107M
#  28350K .......... .......... .......... .......... ..........  113M
#  28400K .......... .......... .......... .......... .......... 82.6M
#  28450K .......... .......... .......... .......... ..........  162M
#  28500K .......... .......... .......... .......... ..........  114M
#  28550K .......... .......... .......... .......... ..........  133M
#  28600K .......... .......... .......... .......... ..........  107M
#  28650K .......... .......... .......... .......... .......... 88.2M
#  28700K .......... .......... .......... .......... ..........  136M
#  28750K .......... .......... .......... .......... ..........  115M
#  28800K .......... .......... .......... .......... .......... 64.7M
#  28850K .......... .......... .......... .......... ..........  202M
#  28900K .......... .......... .......... .......... .......... 68.0M
#  28950K .......... .......... .......... .......... ..........  185M
#  29000K .......... .......... .......... .......... ..........  121M
#  29050K .......... .......... .......... .......... ..........  212M
#  29100K .......... .......... .......... .......... .......... 95.7M
#  29150K .......... .......... .......... .......... ..........  106M
#  29200K .......... .......... .......... .......... ..........  137M
#  29250K .......... .......... .......... .......... .......... 93.5M
#  29300K .......... .......... .......... .......... ..........  128M
#  29350K .......... .......... .......... .......... ..........  104M
#  29400K .......... .......... .......... .......... ..........  124M
#  29450K .......... .......... .......... .......... ..........  120M
#  29500K .......... .......... .......... .......... .......... 87.5M
#  29550K .......... .......... .......... .......... ..........  137M
#  29600K .......... .......... .......... .......... .......... 96.2M
#  29650K .......... .......... .......... .......... ..........  124M
#  29700K .......... .......... .......... .......... ..........  118M
#  29750K .......... .......... .......... .......... ..........  103M
#  29800K .......... .......... .......... .......... ..........  123M
#  29850K .......... .......... .......... .......... .......... 2.40M
#  29900K .......... .......... .......... .......... .......... 88.3M
#  29950K .......... .......... .......... .......... ..........  119M
#  30000K .......... .......... .......... .......... ..........  118M
#  30050K .......... .......... .......... .......... ..........  152M
#  30100K .......... .......... .......... .......... .......... 89.6M
#  30150K .......... .......... .......... .......... ..........  110M
#  30200K .......... .......... .......... .......... ..........  133M
#  30250K .......... .......... .......... .......... .......... 18.5M
#  30300K .......... .......... .......... .......... .......... 74.3M
#  30350K .......... .......... .......... .......... ..........  115M
#  30400K .......... .......... .......... .......... ..........  131M
#  30450K .......... .......... .......... .......... .......... 99.5M
#  30500K .......... .......... .......... .......... ..........  120M
#  30550K .......... .......... .......... .......... .......... 62.4M
#  30600K .......... .......... .......... .......... ..........  203M
#  30650K .......... .......... .......... .......... ..........  161M
#  30700K .......... .......... .......... .......... .......... 75.6M
#  30750K .......... .......... .......... .......... ..........  145M
#  30800K .......... .......... .......... .......... ..........  115M
#  30850K .......... .......... .......... .......... ..........  155M
#  30900K .......... .......... .......... .......... ..........  103M
#  30950K .......... .......... .......... .......... ..........  107M
#  31000K .......... .......... .......... .......... ..........  107M
#  31050K .......... .......... .......... .......... .......... 77.5M
#  31100K .......... .......... .......... .......... ..........  146M
#  31150K .......... .......... .......... .......... ..........  106M
#  31200K .......... .......... .......... .......... ..........  122M
#  31250K .......... .......... .......... .......... ..........  105M
#  31300K .......... .......... .......... .......... ..........  133M
#  31350K .......... .......... .......... .......... ..........  104M
#  31400K .......... .......... .......... .......... .......... 72.5M
#  31450K .......... .......... .......... .......... ..........  193M
#  31500K .......... .......... .......... .......... ..........  107M
#  31550K .......... .......... .......... .......... .......... 77.6M
#  31600K .......... .......... .......... .......... ..........  141M
#  31650K .......... .......... .......... .......... ..........  137M
#  31700K .......... .......... .......... .......... ..........  134M
#  31750K .......... .......... .......... .......... ..........  110M
#  31800K .......... .......... .......... .......... ..........  109M
#  31850K .......... .......... .......... .......... ..........  111M
#  31900K .......... .......... .......... .......... .......... 87.9M
#  31950K .......... .......... .......... .......... ..........  119M
#  32000K .......... .......... .......... .......... ..........  129M
#  32050K .......... .......... .......... .......... ..........  139M
#  32100K .......... .......... .......... .......... .......... 71.4M
#  32150K .......... .......... .......... .......... ..........  204M
#  32200K .......... .......... .......... .......... .......... 72.0M
#  32250K .......... .......... .......... .......... ..........  183M
#  32300K .......... .......... .......... .......... ..........  126M
#  32350K .......... .......... .......... .......... .......... 70.2M
#  32400K .......... .......... .......... .......... ..........  135M
#  32450K .......... .......... .......... .......... ..........  133M
#  32500K .......... .......... .......... .......... .......... 53.0M
#  32550K .......... .......... .......... .......... ..........  196M
#  32600K .......... .......... .......... .......... ..........  173M
#  32650K .......... .......... .......... .......... ..........  157M
#  32700K .......... .......... .......... .......... ..........  103M
#  32750K .......... .......... .......... .......... ..........  111M
#  32800K .......... .......... .......... .......... .......... 95.9M
#  32850K .......... .......... .......... .......... .......... 2.89M
#  32900K .......... .......... .......... .......... ..........  129M
#  32950K .......... .......... .......... .......... ..........  102M
#  33000K .......... .......... .......... .......... .......... 67.1M
#  33050K .......... .......... .......... .......... ..........  108M
#  33100K .......... .......... .......... .......... ..........  125M
#  33150K .......... .......... .......... .......... ..........  116M
#  33200K .......... .......... .......... .......... .......... 79.5M
#  33250K .......... .......... .......... .......... .......... 18.4M
#  33300K .......... .......... .......... .......... .......... 98.2M
#  33350K .......... .......... .......... .......... ..........  125M
#  33400K .......... .......... .......... .......... .......... 58.6M
#  33450K .......... .......... .......... .......... .......... 67.5M
#  33500K .......... .......... .......... .......... ..........  222M
#  33550K .......... .......... .......... .......... ..........  259M
#  33600K .......... .......... .......... .......... .......... 55.2M
#  33650K .......... .......... .......... .......... ..........  121M
#  33700K .......... .......... .......... .......... ..........  106M
#  33750K .......... .......... .......... .......... ..........  122M
#  33800K .......... .......... .......... .......... ..........  138M
#  33850K .......... .......... .......... .......... .......... 17.8M
#  33900K .......... .......... .......... .......... .......... 87.0M
#  33950K .......... .......... .......... .......... ..........  117M
#  34000K .......... .......... .......... .......... .......... 76.8M
#  34050K .......... .......... .......... .......... ..........  137M
#  34100K .......... .......... .......... .......... ..........  121M
#  34150K .......... .......... .......... .......... ..........  130M
#  34200K .......... .......... .......... .......... ..........  141M
#  34250K .......... .......... .......... .......... .......... 72.4M
#  34300K .......... .......... .......... .......... ..........  174M
#  34350K .......... .......... .......... .......... ..........  103M
# ...
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/106.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/386.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/88.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/126.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/283.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/361.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/330.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/270.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/260.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/231.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/153.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/382.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/205.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/254.pt
#   inflating: yeast_cell_in_microstructures_dataset/train/inputs/98.pt
#    creating: yeast_cell_in_microstructures_dataset/val/
#    creating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/bounding_boxes/7.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/.DS_Store
#    creating: yeast_cell_in_microstructures_dataset/val/classes/
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/classes/7.pt
#    creating: yeast_cell_in_microstructures_dataset/val/instances/
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/instances/7.pt
#    creating: yeast_cell_in_microstructures_dataset/val/inputs/
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/243.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/342.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/253.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/105.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/267.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/273.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/140.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/306.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/272.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/363.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/380.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/347.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/285.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/343.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/468.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/358.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/473.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/480.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/339.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/503.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/33.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/238.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/427.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/16.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/359.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/481.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/67.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/399.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/482.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/128.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/34.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/289.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/92.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/393.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/195.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/204.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/255.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/99.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/396.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/334.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/225.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/180.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/324.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/304.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/112.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/392.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/371.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/345.pt
#   inflating: yeast_cell_in_microstructures_dataset/val/inputs/7.pt

# %%
# %pip install lightning==2.4.0

# %%
import lightning as L
import numpy as np
import torch
from torch import Tensor, nn

# %%
torch.manual_seed(42)

# %%
def process_yolo_preds(preds: Tensor, rescaled_anchors: Tensor) -> tuple[Tensor, Tensor, Tensor]:
    """
    Преобразование выходов модели в
    1. Логит наличия объекта (вероятность получается применением сигмоиды)
    2. Положение рамки относительно ячейки в формате cxcywh
    3. Логиты классов (вероятности получаются применением softmax)
    """
    rescaled_anchors = rescaled_anchors.view(1, len(rescaled_anchors), 1, 1, 2)
    box_predictions = preds[..., 1:5].clone()

    box_predictions[..., 0:2] = torch.sigmoid(box_predictions[..., 0:2])
    box_predictions[..., 2:] = torch.exp(box_predictions[..., 2:]) * rescaled_anchors

    scores = preds[..., 0:1]
    return scores, box_predictions, preds[..., 5:]

# %%
GRID_SIZE = 8
IMAGE_SIZE = 256
ANCHORS = [
    [48, 72],
    [64, 64],
    [72, 48],
]
BATCH_SIZE = 8
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
rescaled_anchors = torch.tensor(ANCHORS,device = device) / IMAGE_SIZE * GRID_SIZE

# %%
class CNNBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, **kwargs):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activation = nn.LeakyReLU(0.1)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return self.activation(x)

class TinyYOLO(nn.Module):
    def __init__(self, num_classes: int = 2, num_anchors: int = len(ANCHORS), in_channels: int = 1) -> None:
        super().__init__()
        self.num_classes = num_classes
        self.in_channels = in_channels
        self.num_anchors = num_anchors
        self.layers = nn.Sequential(
            CNNBlock(1, 16, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(16, 32, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(32, 64, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(64, 128, kernel_size=3, stride=2, padding=1, groups=8),
            CNNBlock(128, 256, kernel_size=3, stride=1, padding=1, groups=8),
            CNNBlock(256, 256, kernel_size=3, stride=1, padding=1, groups=16),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(256, num_anchors * (num_classes + 5), kernel_size=1)
        )

    def forward(self, x: Tensor) -> Tensor:
        x = self.layers(x)
        B, _, W, H = x.shape
        x = x.view(B, self.num_anchors, self.num_classes + 5, W, H)  # B A F W H
        x = x.permute(0, 1, 3, 4, 2)  # B A W H F
        return x

# %%
def iou_wh(wh1: Tensor, wh2: Tensor) -> Tensor:
    # IoU based on width and height of bboxes

    # intersection
    intersection_area = torch.min(wh1[..., 0], wh2[..., 0]) * torch.min(wh1[..., 1], wh2[..., 1])

    # union
    box1_area = wh1[..., 0] * wh1[..., 1]
    box2_area = wh2[..., 0] * wh2[..., 1]
    union_area = box1_area + box2_area - intersection_area

    iou_score = intersection_area / union_area
    return iou_score


def boxes_to_cells(
    boxes: Tensor,
    classes: Tensor,
    rescaled_anchors: Tensor,
    grid_size: int = 8,
    ignore_iou_thresh: float = 0.5,
) -> Tensor:
    """
    Переводит bbox представление в клеточное представление, где каждая рамка -
    (id класса, вероятность нахождения объекта, cx, cy, w, h), а клеточное представление
    имеет размер (batch_size, n_anchors, grid_size, grid_size, 6), в последней размерности
    хранятся признаки ячейки: класс объекта, вероятность объекта, координаты и размеры рамки
    относительно ячейки

    Args:
        boxes (Tensor): тензор со всеми рамками
        classes (Tensor): тензор с id классов объектов
        rescaled_anchors (Tensor): тензор размера (n_anchors, 2) с размерами якорей в долях от размеров ячейки
        grid_size (int): размер сетки,
        ignore_iou_thresh (float, optional): значение IoU для рамок, при котором ячейка,
            занятая более чем одним объектом, будет специально помечена для игнорирования
    """
    targets = torch.zeros((len(rescaled_anchors), grid_size, grid_size, 6))

    # Каждой рамке сопоставляем клетку и наиболее подходящий якорь
    for box, class_label in zip(boxes, classes):
        iou_anchors = iou_wh(box[2:4], rescaled_anchors / grid_size)
        anchor_indices = iou_anchors.argsort(descending=True, dim=0)
        x, y, width, height = box

        # Относим рамку к наиболее подходящему якорю
        has_anchor = False
        for anchor_idx in anchor_indices:
            s = grid_size

            # Определяем клетку, к которой относится рамка
            i, j = int(s * y), int(s * x)
            anchor_taken = targets[anchor_idx, i, j, 0]

            # Проверяем, доступен ли якорная рамка для текущей ячейки
            if not anchor_taken and not has_anchor:
                # Пересчитываем координаты по отношению к клетке
                x_cell, y_cell = s * x - j, s * y - i
                width_cell, height_cell = (width * s, height * s)
                box_coordinates = torch.tensor([x_cell, y_cell, width_cell, height_cell])

                # Заполняем содержимое для выбранной клетки
                targets[anchor_idx, i, j, 0] = 1  # указатель, что в клетке есть объект
                targets[anchor_idx, i, j, 1:5] = box_coordinates
                targets[anchor_idx, i, j, 5] = int(class_label)

                has_anchor = True

            # Если якорь уже выбран, проверим IoU, если больше threshold - пометим клетку -1
            elif not anchor_taken and iou_anchors[anchor_idx] > ignore_iou_thresh:
                targets[anchor_idx, i, j, 0] = -1

    return targets

# %%
from torch.utils.data import DataLoader, Dataset
class YeastDetectionDataset(Dataset):
    def __init__(
        self, subset_dir: Path, anchors: list[tuple[int, int]] = ANCHORS, image_size: int = IMAGE_SIZE, grid_size: int = GRID_SIZE
    ) -> None:
        super().__init__()
        self.subset_dir = subset_dir
        self.items = list((self.subset_dir / "inputs").glob("*.pt"))
        # Ignore IoU threshold
        self.ignore_iou_thresh = 0.5
        self.rescaled_anchors = torch.tensor(anchors) / image_size * grid_size
        self.grid_size = grid_size
        self.image_size = image_size

    def __len__(self) -> int:
        return len(self.items)

    def __getitem__(self, index: int) -> tuple[Tensor, Tensor]:
        image_path = self.items[index]
        # load everything
        image = torch.load(image_path, weights_only=True).unsqueeze(0)
        classes = (
            torch.load(self.subset_dir / "classes" / image_path.parts[-1], weights_only=True) + 1
        )
        boxes = torch.load(
            self.subset_dir / "bounding_boxes" / image_path.parts[-1], weights_only=True
        )
        boxes = box_convert(boxes, "xyxy", "cxcywh") / self.image_size

        # convert boxes to cells
        targets = boxes_to_cells(
            boxes, classes, self.rescaled_anchors, self.grid_size, self.ignore_iou_thresh
        )
        return image, targets

# %%
def cells_to_bboxes(cells: Tensor, rescaled_anchors: Tensor, is_predictions=False) -> Tensor:
    """
    Переводит клеточное представление в bbox представление, где каждая рамка -
    (id класса, вероятность нахождения объекта, cx, cy, w, h), а клеточное представление
    имеет размер (batch_size, n_anchors, grid_size, grid_size, 6), в последней размерности
    хранятся признаки ячейки: класс объекта, вероятность объекта, координаты и размеры рамки
    относительно ячейки

    Args:
        cells (Tensor): тензор размера (batch_size, n_anchors, width, height, 6)
        rescaled_anchors (Tensor): тензор размера (n_anchors, 2) с размерами якорей в долях от размеров ячейки
        is_predictions (bool, optional): являются ли входные ячейки предсказаниями или верной аннотацией.
    """

    if is_predictions:
        scores, box_predictions, logits = process_yolo_preds(cells, rescaled_anchors)
        scores = torch.sigmoid(scores)
        best_class = torch.argmax(logits, dim=-1).unsqueeze(-1) + 1

    else:
        box_predictions = cells[..., 1:5].clone()
        scores = cells[..., 0:1]
        best_class = cells[..., 5:6]

    # масштабируем размер рамок [0, grid_size] -> [0, 1]
    _, _, H, W, _ = cells.shape
    range_y, range_x = torch.meshgrid(
        torch.arange(H, dtype=cells.dtype, device=cells.device),
        torch.arange(W, dtype=cells.dtype, device=cells.device),
        indexing="ij",
    )
    x = torch.cat(
        [
            best_class,
            scores,
            (box_predictions[..., 0:1] + range_x[None, None, :, :, None]) / W,  # X center
            (box_predictions[..., 1:2] + range_y[None, None, :, :, None]) / H,  # Y center
            box_predictions[..., 2:3] / W,  # Width
            box_predictions[..., 3:4] / H,  # Height
        ],
        -1,
    )

    return x.view(-1, 6)

# %%
class YOLOLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        self.bce = nn.BCEWithLogitsLoss()
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, pred: Tensor, target: Tensor, anchors: Tensor) -> Tensor:
        # ниже входные тензоры будут меняться на месте, так что склонируем их
        pred = pred.clone()
        target = target.clone()

        # разделяем рамки на содержащие объекты и не содержащие
        # NB: ещё могут быть -1, куда отнеслось более 1 объекта - их не учитываем
        obj = target[..., 0] == 1
        no_obj = target[..., 0] == 0

        # преобразуем предсказания bbox
        scores, pred_boxes, logits = process_yolo_preds(pred, anchors)

        # no object loss: кросс-энтропия вместо MSE
        no_object_loss = self.bce(
            (scores[no_obj]),
            (target[..., 0:1][no_obj]),
        )

        # object loss: учим предсказывать IoU
        ious = intersection_over_union(pred_boxes[obj], target[..., 1:5][obj]).detach()
        object_loss = self.mse(scores[obj].sigmoid(), ious * target[..., 0:1][obj])

        # box coordinate loss: логарифмируем размеры рамок перед расчётом MSE
        anchors = anchors.reshape(1, len(anchors), 1, 1, 2)
        pred[..., 1:3] = pred[..., 1:3].sigmoid()
        target[..., 3:5] = torch.log(1e-6 + target[..., 3:5] / anchors)
        box_loss = self.mse(pred[..., 1:5][obj], target[..., 1:5][obj])

        # class loss: здесь всё обычно
        class_loss = self.cross_entropy(logits[obj], target[..., 5][obj].long() - 1)

        # Total loss
        return box_loss + object_loss + no_object_loss + class_loss

# %%
from pathlib import Path
from lightning.pytorch.utilities.types import EVAL_DATALOADERS, TRAIN_DATALOADERS

from torchmetrics.functional.detection import intersection_over_union
from torchvision.ops.boxes import box_convert

class YeastDetectionDataModule(L.LightningDataModule):
    def __init__(
        self,
        datadir: Path = Path("yeast_cell_in_microstructures_dataset"),
        anchors: list[tuple[int, int]] = ANCHORS,
        image_size: int = IMAGE_SIZE,
        grid_size: int = GRID_SIZE,
        batch_size: int = BATCH_SIZE,
        train_subdir: str = "train",
        val_subdir: str = "val",
        test_subdir: str = "test",
    ):
        super().__init__()
        self.anchors = anchors
        self.image_size = image_size
        self.grid_size = grid_size
        self.batch_size = batch_size
        self.train_dir = datadir / train_subdir
        self.val_dir = datadir / val_subdir
        self.test_dir = datadir / test_subdir

    def setup(self, stage: str) -> None:
        if stage in ("fit", "validate"):
            self.val_dataset = YeastDetectionDataset(self.val_dir, anchors=self.anchors)
        if stage == "fit":
            self.train_dataset = YeastDetectionDataset(self.train_dir, anchors=self.anchors)
        elif stage == "test":
            self.test_dataset = YeastDetectionDataset(self.test_dir, anchors=self.anchors)

    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True
        )

    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=False
        )

    def test_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=False
        )

# %%
def map_transform(preds, y):
    predicted_boxes = []
    target_boxes = []
    # итерируемся по элементам батча, собирая пердсказанные и верные рамки
    for i in range(len(y)):
        # получаем предсказанные рамки
        pred_boxes = cells_to_bboxes(preds[i:i+1], rescaled_anchors, is_predictions=True)
        # ВАЖНО: делаем non-max suppression ДО расчёта метрик
        pred_boxes = pred_boxes[nms(box_convert(pred_boxes[:, 2:], "cxcywh", "xyxy"), pred_boxes[:, 1], iou_threshold=0.3)]
        predicted_boxes.append(
            dict(
                boxes=pred_boxes[:, 2:],
                scores=pred_boxes[:, 1],
                labels=pred_boxes[:, 0].long(),
            )
        )
        true_boxes = cells_to_bboxes(y[i:i+1], rescaled_anchors)
        true_boxes = true_boxes[true_boxes[:, 1] == 1]

        target_boxes.append(
            dict(
                boxes=true_boxes[:, 2:],
                labels=true_boxes[:, 0].long(),
            )
        )
    return predicted_boxes, target_boxes

# %%
from typing import Any
from lightning.pytorch.utilities.types import STEP_OUTPUT
from torchmetrics.detection import MeanAveragePrecision
from torchvision.ops.boxes import nms
from lightning.pytorch.loggers import TensorBoardLogger

class Lit(L.LightningModule):
    def __init__(self, model: nn.Module, learning_rate: float = 0.001) -> None:
        super().__init__()
        self.save_hyperparameters()
        self.model = model
        self.learning_rate = learning_rate
        self.map = MeanAveragePrecision(iou_type="bbox", box_format="cxcywh", class_metrics=True)

    def training_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT:
        x, y = batch
        y_hat = self.model(x)

        loss = YOLOLoss().forward(pred=y_hat, target=y, anchors=rescaled_anchors)
        self.log("train_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT | None:
        x, y = batch
        y_hat = self.model(x)
        loss = YOLOLoss().forward(pred=y_hat, target=y, anchors=rescaled_anchors)

        self.map(*map_transform(y_hat, y))
        self.log("val_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        return {
            "loss": loss,
        }

    def on_validation_epoch_end(self) -> None:
        self.log("val_map", self.map.compute()['map'], on_epoch=True, on_step=False, prog_bar=True)
        self.map.reset()


    def configure_optimizers(self) -> dict[str, Any]:
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate, weight_decay=0.0001)
        return {
            "optimizer": optimizer,
            "lr_scheduler": torch.optim.lr_scheduler.MultiStepLR(
                optimizer, milestones=[5, 10, 15]
            ),
        }

# %% [markdown]
# ### Задание 1 (3 балла). Цикл обучения с расчётом Mean Average Precision
#
# Запустите обучение модели из практики на всём обучающем датасете, выведите значение $mAP$ на валидационном датасете после окончания обучения.
#
# В этом задании добейтесь $mAP > 0.3$, если всё сделано правильно - для этого должно хватать 30-50 эпох.

# %%
from lightning.pytorch.loggers import TensorBoardLogger
trainer = L.Trainer(
    accelerator="auto",
    max_epochs=35,
    logger=TensorBoardLogger(save_dir="."),
)
lit_module = Lit(
    model=TinyYOLO(), learning_rate=0.001
)
datamodule = YeastDetectionDataModule(image_size=256, anchors=ANCHORS, batch_size=BATCH_SIZE)
trainer.fit(model=lit_module, datamodule=datamodule,)
trainer.validate(model=lit_module, datamodule=datamodule,)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | TinyYOLO             | 109 K  | train
# 1 | map   | MeanAveragePrecision | 0      | train
# -------------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 29        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  7.25it/s]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (37) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|██████████| 37/37 [00:01<00:00, 22.43it/s, v_num=16]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.46it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.70it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.74it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.12it/s]
# Epoch 1: 100%|██████████| 37/37 [00:01<00:00, 22.48it/s, v_num=16, val_loss=0.286, val_map=0.164, train_loss=0.590]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.32it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.44it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.36it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.95it/s]
# Epoch 2: 100%|██████████| 37/37 [00:01<00:00, 22.37it/s, v_num=16, val_loss=0.155, val_map=0.206, train_loss=0.178]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.50it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.71it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.72it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.40it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.97it/s]
# Epoch 3: 100%|██████████| 37/37 [00:01<00:00, 22.06it/s, v_num=16, val_loss=0.131, val_map=0.294, train_loss=0.129]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.30it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.50it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.09it/s]
# Epoch 4: 100%|██████████| 37/37 [00:01<00:00, 22.03it/s, v_num=16, val_loss=0.122, val_map=0.311, train_loss=0.102]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.06it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.31it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.88it/s]
# Epoch 5: 100%|██████████| 37/37 [00:01<00:00, 22.78it/s, v_num=16, val_loss=0.121, val_map=0.358, train_loss=0.0848]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.04it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.44it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.30it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.88it/s]
# Epoch 6: 100%|██████████| 37/37 [00:01<00:00, 22.23it/s, v_num=16, val_loss=0.117, val_map=0.369, train_loss=0.0722]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.01it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.71it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.48it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.05it/s]
# Epoch 7: 100%|██████████| 37/37 [00:01<00:00, 22.03it/s, v_num=16, val_loss=0.118, val_map=0.364, train_loss=0.0711]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.51it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.80it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.78it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.64it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.48it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.05it/s]
# Epoch 8: 100%|██████████| 37/37 [00:01<00:00, 21.90it/s, v_num=16, val_loss=0.120, val_map=0.367, train_loss=0.0691]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.35it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.67it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.77it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.65it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.48it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.05it/s]
# Epoch 9: 100%|██████████| 37/37 [00:01<00:00, 21.89it/s, v_num=16, val_loss=0.123, val_map=0.359, train_loss=0.0666]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.98it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.46it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.05it/s]
# Epoch 10: 100%|██████████| 37/37 [00:01<00:00, 22.16it/s, v_num=16, val_loss=0.123, val_map=0.370, train_loss=0.0658]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.05it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.45it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.30it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.87it/s]
# Epoch 11: 100%|██████████| 37/37 [00:01<00:00, 22.38it/s, v_num=16, val_loss=0.126, val_map=0.370, train_loss=0.0633]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.16it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.32it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
# Epoch 12: 100%|██████████| 37/37 [00:01<00:00, 22.51it/s, v_num=16, val_loss=0.124, val_map=0.366, train_loss=0.0629]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.09it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.36it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.92it/s]
# Epoch 13: 100%|██████████| 37/37 [00:01<00:00, 22.78it/s, v_num=16, val_loss=0.127, val_map=0.365, train_loss=0.0635]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.10it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.77it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.69it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.51it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.09it/s]
# Epoch 14: 100%|██████████| 37/37 [00:01<00:00, 21.82it/s, v_num=16, val_loss=0.123, val_map=0.365, train_loss=0.0636]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.07it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.43it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.03it/s]
# Epoch 15: 100%|██████████| 37/37 [00:01<00:00, 22.21it/s, v_num=16, val_loss=0.126, val_map=0.368, train_loss=0.0634]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.01it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.31it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.87it/s]
# Epoch 16: 100%|██████████| 37/37 [00:01<00:00, 22.08it/s, v_num=16, val_loss=0.123, val_map=0.368, train_loss=0.0626]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.82it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.28it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# Epoch 17: 100%|██████████| 37/37 [00:01<00:00, 22.43it/s, v_num=16, val_loss=0.126, val_map=0.367, train_loss=0.0622]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.27it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.69it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.44it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.00it/s]
# Epoch 18: 100%|██████████| 37/37 [00:01<00:00, 20.62it/s, v_num=16, val_loss=0.128, val_map=0.368, train_loss=0.0622]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.95it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.16it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.28it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.23it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.14it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.70it/s]
# Epoch 19: 100%|██████████| 37/37 [00:01<00:00, 21.58it/s, v_num=16, val_loss=0.127, val_map=0.367, train_loss=0.0629]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.04it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.27it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# Epoch 20: 100%|██████████| 37/37 [00:01<00:00, 22.44it/s, v_num=16, val_loss=0.126, val_map=0.369, train_loss=0.0622]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.06it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.31it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.87it/s]
# Epoch 21: 100%|██████████| 37/37 [00:01<00:00, 22.34it/s, v_num=16, val_loss=0.129, val_map=0.365, train_loss=0.0618]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.15it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.28it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.85it/s]
# Epoch 22: 100%|██████████| 37/37 [00:01<00:00, 21.90it/s, v_num=16, val_loss=0.127, val_map=0.366, train_loss=0.0622]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.13it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.75it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.64it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.64it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# Epoch 23: 100%|██████████| 37/37 [00:01<00:00, 21.94it/s, v_num=16, val_loss=0.129, val_map=0.368, train_loss=0.0638]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.22it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.29it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.86it/s]
# Epoch 24: 100%|██████████| 37/37 [00:01<00:00, 22.43it/s, v_num=16, val_loss=0.128, val_map=0.368, train_loss=0.0636]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.05it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.29it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.86it/s]
# Epoch 25: 100%|██████████| 37/37 [00:01<00:00, 22.42it/s, v_num=16, val_loss=0.125, val_map=0.368, train_loss=0.0624]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.29it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.44it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.37it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.95it/s]
# Epoch 26: 100%|██████████| 37/37 [00:01<00:00, 21.89it/s, v_num=16, val_loss=0.128, val_map=0.367, train_loss=0.062]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.31it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.73it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.78it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.64it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.44it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.03it/s]
# Epoch 27: 100%|██████████| 37/37 [00:01<00:00, 21.93it/s, v_num=16, val_loss=0.126, val_map=0.367, train_loss=0.0626]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.07it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.90it/s]
# Epoch 28: 100%|██████████| 37/37 [00:01<00:00, 21.91it/s, v_num=16, val_loss=0.126, val_map=0.367, train_loss=0.0626]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.97it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.45it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.24it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.80it/s]
# Epoch 29: 100%|██████████| 37/37 [00:01<00:00, 22.45it/s, v_num=16, val_loss=0.129, val_map=0.368, train_loss=0.0623]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
# Epoch 30: 100%|██████████| 37/37 [00:01<00:00, 21.98it/s, v_num=16, val_loss=0.124, val_map=0.363, train_loss=0.0612]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.52it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.73it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.65it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.55it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.12it/s]
# Epoch 31: 100%|██████████| 37/37 [00:01<00:00, 22.04it/s, v_num=16, val_loss=0.129, val_map=0.368, train_loss=0.0619]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.12it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.46it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.06it/s]
# Epoch 32: 100%|██████████| 37/37 [00:01<00:00, 21.87it/s, v_num=16, val_loss=0.126, val_map=0.368, train_loss=0.062]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.04it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.35it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 33: 100%|██████████| 37/37 [00:01<00:00, 21.82it/s, v_num=16, val_loss=0.126, val_map=0.364, train_loss=0.0623]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.13it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.42it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
# Epoch 34: 100%|██████████| 37/37 [00:01<00:00, 21.91it/s, v_num=16, val_loss=0.126, val_map=0.367, train_loss=0.0627]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.87it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.29it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.86it/s]
# Epoch 34: 100%|██████████| 37/37 [00:03<00:00, 10.44it/s, v_num=16, val_loss=0.130, val_map=0.361, train_loss=0.0625]
# `Trainer.fit` stopped: `max_epochs=35` reached.
# Epoch 34: 100%|██████████| 37/37 [00:03<00:00, 10.33it/s, v_num=16, val_loss=0.130, val_map=0.361, train_loss=0.0625]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.46it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.12970031797885895    │
# │          val_map          │    0.36059409379959106    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.12970031797885895, 'val_map': 0.36059409379959106}]

# %% [markdown]
# ### Задание 2 (2 балла). YoloV3 loss
#
# Мы упоминали, что на практике использовалась не совсем та же самая ошибка, что и в YOLO. В этом задании исправьте в классе YoloLoss ошибку регрессии, приведя её в соответствие с тем, как она описана в статье [YOLOv3: An Incremental Improvement](https://arxiv.org/abs/1804.02767) (см. раздел 2.1. Bounding Box Prediction).
#
# Запустите обучение с изменённой ошибкой, добейтесь $mAP > 0.3$

# %%
class YOLOv3Loss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        self.bce = nn.BCEWithLogitsLoss()
        self.cross_entropy = nn.CrossEntropyLoss()

    def forward(self, pred: Tensor, target: Tensor, anchors: Tensor) -> Tensor:
        # ниже входные тензоры будут меняться на месте, так что склонируем их
        pred = pred.clone()
        target = target.clone()

        # разделяем рамки на содержащие объекты и не содержащие
        # NB: ещё могут быть -1, куда отнеслось более 1 объекта - их не учитываем
        obj = target[..., 0] == 1
        no_obj = target[..., 0] == 0

        # преобразуем предсказания bbox
        scores, pred_boxes, logits = process_yolo_preds(pred, anchors)

        # no object loss: кросс-энтропия вместо MSE
        no_object_loss = self.bce(
            (scores[no_obj]),
            (target[..., 0:1][no_obj]),
        )

        # object loss: учим предсказывать IoU
        ious = intersection_over_union(pred_boxes[obj], target[..., 1:5][obj]).detach()
        object_loss = self.mse(scores[obj].sigmoid(), ious * target[..., 0:1][obj])

        # box coordinate loss: логарифмируем размеры рамок перед расчётом MSE
        anchors = anchors.reshape(1, len(anchors), 1, 1, 2)
        pred[..., 1:3] = pred[..., 1:3].sigmoid()
        pred[..., 3:5] = torch.sqrt(anchors * torch.exp(pred[..., 3:5]))
        target[..., 3:5] = torch.sqrt(target[..., 3:5])
        box_loss = self.mse(pred[..., 1:5][obj], target[..., 1:5][obj])

        # class loss: здесь всё обычно
        class_loss = self.cross_entropy(logits[obj], target[..., 5][obj].long() - 1)

        # Total loss
        return box_loss + object_loss + no_object_loss + class_loss

# %%
class Lit_v3(L.LightningModule):
    def __init__(self, model: nn.Module, learning_rate: float = 0.001) -> None:
        super().__init__()
        self.save_hyperparameters()
        self.model = model
        self.learning_rate = learning_rate
        self.map = MeanAveragePrecision(iou_type="bbox", box_format="cxcywh", class_metrics=True)

    def training_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT:
        x, y = batch
        y_hat = self.model(x)

        loss = YOLOv3Loss().forward(pred=y_hat, target=y, anchors=rescaled_anchors)
        self.log("train_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(
        self, batch: tuple[Tensor, Tensor], batch_idx: int
    ) -> STEP_OUTPUT | None:
        x, y = batch
        y_hat = self.model(x)
        loss = YOLOv3Loss().forward(pred=y_hat, target=y, anchors=rescaled_anchors)

        self.map(*map_transform(y_hat, y))
        self.log("val_loss", loss, on_epoch=True, on_step=False, prog_bar=True)
        return {
            "loss": loss,
        }

    def on_validation_epoch_end(self) -> None:
        self.log("val_map", self.map.compute()['map'], on_epoch=True, on_step=False, prog_bar=True)
        self.map.reset()


    def configure_optimizers(self) -> dict[str, Any]:
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate, weight_decay=0.0001)
        return {
            "optimizer": optimizer,
            "lr_scheduler": torch.optim.lr_scheduler.MultiStepLR(
                optimizer, milestones=[5, 10, 15]
            ),
        }

# %%
trainer_v3 = L.Trainer(
    accelerator="auto",
    max_epochs=50,
    logger=TensorBoardLogger(save_dir="."),
)
lit_module_v3 = Lit_v3(
    model=TinyYOLO(), learning_rate=0.001
)
datamodule = YeastDetectionDataModule(image_size=256, anchors=ANCHORS, batch_size=BATCH_SIZE)
trainer_v3.fit(model=lit_module_v3, datamodule=datamodule,)
trainer_v3.validate(model=lit_module_v3, datamodule=datamodule,)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | TinyYOLO             | 109 K  | train
# 1 | map   | MeanAveragePrecision | 0      | train
# -------------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 29        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (37) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|██████████| 37/37 [00:01<00:00, 21.73it/s, v_num=21]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.68it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.92it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.84it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.81it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.75it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.38it/s]
# Epoch 1: 100%|██████████| 37/37 [00:01<00:00, 23.14it/s, v_num=21, val_loss=0.319, val_map=0.0612, train_loss=0.642]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.19it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.92it/s]
# Epoch 2: 100%|██████████| 37/37 [00:01<00:00, 22.04it/s, v_num=21, val_loss=0.158, val_map=0.227, train_loss=0.213]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.67it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.51it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.10it/s]
# Epoch 3: 100%|██████████| 37/37 [00:01<00:00, 21.81it/s, v_num=21, val_loss=0.123, val_map=0.284, train_loss=0.138]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.04it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.44it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.03it/s]
# Epoch 4: 100%|██████████| 37/37 [00:01<00:00, 21.92it/s, v_num=21, val_loss=0.109, val_map=0.283, train_loss=0.109]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.05it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.38it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.38it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# Epoch 5: 100%|██████████| 37/37 [00:01<00:00, 21.79it/s, v_num=21, val_loss=0.114, val_map=0.305, train_loss=0.0916]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.13it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.38it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# Epoch 6: 100%|██████████| 37/37 [00:01<00:00, 22.20it/s, v_num=21, val_loss=0.106, val_map=0.320, train_loss=0.0798]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.17it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.39it/s]
#                                                                    /s]
# Epoch 7: 100%|██████████| 37/37 [00:01<00:00, 22.36it/s, v_num=21, val_loss=0.109, val_map=0.323, train_loss=0.0797]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.57it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.80it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.83it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.65it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.49it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.07it/s]
# Epoch 8: 100%|██████████| 37/37 [00:01<00:00, 22.10it/s, v_num=21, val_loss=0.109, val_map=0.319, train_loss=0.077]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.22it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.73it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.14it/s]
# Epoch 9: 100%|██████████| 37/37 [00:01<00:00, 21.73it/s, v_num=21, val_loss=0.107, val_map=0.322, train_loss=0.0748]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.30it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.44it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.36it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 10: 100%|██████████| 37/37 [00:01<00:00, 21.83it/s, v_num=21, val_loss=0.112, val_map=0.324, train_loss=0.0727]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.20it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.35it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 11: 100%|██████████| 37/37 [00:01<00:00, 21.98it/s, v_num=21, val_loss=0.110, val_map=0.327, train_loss=0.0703]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.10it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.42it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.00it/s]
# Epoch 12: 100%|██████████| 37/37 [00:01<00:00, 22.28it/s, v_num=21, val_loss=0.111, val_map=0.322, train_loss=0.0711]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.55it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.84it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.79it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.46it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.03it/s]
# Epoch 13: 100%|██████████| 37/37 [00:01<00:00, 21.73it/s, v_num=21, val_loss=0.108, val_map=0.320, train_loss=0.070]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.54it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.13it/s]
# Epoch 14: 100%|██████████| 37/37 [00:01<00:00, 21.93it/s, v_num=21, val_loss=0.111, val_map=0.324, train_loss=0.0701]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.05it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.36it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.94it/s]
# Epoch 15: 100%|██████████| 37/37 [00:01<00:00, 22.54it/s, v_num=21, val_loss=0.107, val_map=0.326, train_loss=0.0696]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.30it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.44it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.01it/s]
# Epoch 16: 100%|██████████| 37/37 [00:01<00:00, 22.39it/s, v_num=21, val_loss=0.110, val_map=0.325, train_loss=0.0697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.53it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.85it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.72it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.66it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.56it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.13it/s]
# Epoch 17: 100%|██████████| 37/37 [00:01<00:00, 21.56it/s, v_num=21, val_loss=0.110, val_map=0.324, train_loss=0.070]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.55it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.91it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.71it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.70it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.64it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.24it/s]
# Epoch 18: 100%|██████████| 37/37 [00:01<00:00, 21.79it/s, v_num=21, val_loss=0.109, val_map=0.329, train_loss=0.0701]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.12it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.37it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.95it/s]
# Epoch 19: 100%|██████████| 37/37 [00:01<00:00, 22.29it/s, v_num=21, val_loss=0.109, val_map=0.328, train_loss=0.0695]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.28it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.66it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.42it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
# Epoch 20: 100%|██████████| 37/37 [00:01<00:00, 21.93it/s, v_num=21, val_loss=0.112, val_map=0.327, train_loss=0.0697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.54it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.90it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.92it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.74it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.72it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.66it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.26it/s]
# Epoch 21: 100%|██████████| 37/37 [00:01<00:00, 21.30it/s, v_num=21, val_loss=0.112, val_map=0.324, train_loss=0.0703]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.17it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.45it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.43it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.01it/s]
# Epoch 22: 100%|██████████| 37/37 [00:01<00:00, 22.32it/s, v_num=21, val_loss=0.108, val_map=0.326, train_loss=0.0701]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.17it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.34it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.92it/s]
# Epoch 23: 100%|██████████| 37/37 [00:01<00:00, 22.27it/s, v_num=21, val_loss=0.111, val_map=0.324, train_loss=0.0703]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.13it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.40it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.97it/s]
# Epoch 24: 100%|██████████| 37/37 [00:01<00:00, 22.11it/s, v_num=21, val_loss=0.108, val_map=0.326, train_loss=0.0699]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.20it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.30it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.86it/s]
# Epoch 25: 100%|██████████| 37/37 [00:01<00:00, 22.61it/s, v_num=21, val_loss=0.110, val_map=0.327, train_loss=0.0699]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.33it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.65it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.67it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.38it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# Epoch 26: 100%|██████████| 37/37 [00:01<00:00, 21.98it/s, v_num=21, val_loss=0.109, val_map=0.327, train_loss=0.0697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.70it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.95it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  6.02it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.76it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.67it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.25it/s]
# Epoch 27: 100%|██████████| 37/37 [00:01<00:00, 21.94it/s, v_num=21, val_loss=0.111, val_map=0.325, train_loss=0.0688]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.12it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.52it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.12it/s]
# Epoch 28: 100%|██████████| 37/37 [00:01<00:00, 21.63it/s, v_num=21, val_loss=0.109, val_map=0.326, train_loss=0.0688]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.40it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.82it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.85it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.58it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.18it/s]
# Epoch 29: 100%|██████████| 37/37 [00:01<00:00, 21.75it/s, v_num=21, val_loss=0.108, val_map=0.326, train_loss=0.0698]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  6.00it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.71it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.15it/s]
# Epoch 30: 100%|██████████| 37/37 [00:01<00:00, 21.51it/s, v_num=21, val_loss=0.109, val_map=0.323, train_loss=0.0694]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.20it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.76it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.52it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.10it/s]
# Epoch 31: 100%|██████████| 37/37 [00:01<00:00, 22.57it/s, v_num=21, val_loss=0.111, val_map=0.330, train_loss=0.0702]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.32it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
# Epoch 32: 100%|██████████| 37/37 [00:01<00:00, 22.11it/s, v_num=21, val_loss=0.111, val_map=0.328, train_loss=0.0696]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.62it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.84it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.64it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.51it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.10it/s]
# Epoch 33: 100%|██████████| 37/37 [00:01<00:00, 21.87it/s, v_num=21, val_loss=0.110, val_map=0.326, train_loss=0.069]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.54it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.14it/s]
# Epoch 34: 100%|██████████| 37/37 [00:01<00:00, 21.96it/s, v_num=21, val_loss=0.110, val_map=0.328, train_loss=0.0696]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.99it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.41it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.01it/s]
# Epoch 35: 100%|██████████| 37/37 [00:01<00:00, 22.09it/s, v_num=21, val_loss=0.109, val_map=0.328, train_loss=0.0694]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.44it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.67it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.45it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.04it/s]
# Epoch 36: 100%|██████████| 37/37 [00:01<00:00, 21.75it/s, v_num=21, val_loss=0.108, val_map=0.327, train_loss=0.0697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.75it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.84it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.66it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.59it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.18it/s]
# Epoch 37: 100%|██████████| 37/37 [00:01<00:00, 21.95it/s, v_num=21, val_loss=0.112, val_map=0.325, train_loss=0.0689]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.40it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.98it/s]
# Epoch 38: 100%|██████████| 37/37 [00:01<00:00, 21.97it/s, v_num=21, val_loss=0.112, val_map=0.327, train_loss=0.0697]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.03it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.44it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.25it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.80it/s]
# Epoch 39: 100%|██████████| 37/37 [00:01<00:00, 22.24it/s, v_num=21, val_loss=0.112, val_map=0.323, train_loss=0.0687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.03it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.60it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.47it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.41it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.98it/s]
# Epoch 40: 100%|██████████| 37/37 [00:01<00:00, 22.20it/s, v_num=21, val_loss=0.111, val_map=0.324, train_loss=0.0702]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.31it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.31it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.88it/s]
# Epoch 41: 100%|██████████| 37/37 [00:01<00:00, 21.73it/s, v_num=21, val_loss=0.110, val_map=0.328, train_loss=0.0694]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.67it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.59it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.55it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.15it/s]
# Epoch 42: 100%|██████████| 37/37 [00:01<00:00, 21.58it/s, v_num=21, val_loss=0.112, val_map=0.321, train_loss=0.0687]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.61it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.68it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.53it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# Epoch 43: 100%|██████████| 37/37 [00:01<00:00, 21.88it/s, v_num=21, val_loss=0.106, val_map=0.327, train_loss=0.069]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.18it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.55it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.63it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.51it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# Epoch 44: 100%|██████████| 37/37 [00:01<00:00, 21.92it/s, v_num=21, val_loss=0.110, val_map=0.326, train_loss=0.0684]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.54it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.45it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.40it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
# Epoch 45: 100%|██████████| 37/37 [00:01<00:00, 21.92it/s, v_num=21, val_loss=0.109, val_map=0.322, train_loss=0.0693]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.44it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.76it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.75it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.58it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.52it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.42it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
# Epoch 46: 100%|██████████| 37/37 [00:01<00:00, 21.82it/s, v_num=21, val_loss=0.109, val_map=0.326, train_loss=0.0685]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.46it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.78it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.86it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.74it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.64it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.23it/s]
# Epoch 47: 100%|██████████| 37/37 [00:01<00:00, 21.54it/s, v_num=21, val_loss=0.111, val_map=0.321, train_loss=0.0698]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.10it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.53it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.62it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.51it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.47it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.07it/s]
# Epoch 48: 100%|██████████| 37/37 [00:01<00:00, 21.90it/s, v_num=21, val_loss=0.109, val_map=0.328, train_loss=0.0692]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.56it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.91it/s]
# Epoch 49: 100%|██████████| 37/37 [00:01<00:00, 22.29it/s, v_num=21, val_loss=0.109, val_map=0.326, train_loss=0.0682]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.07it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.50it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.57it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
# Epoch 49: 100%|██████████| 37/37 [00:03<00:00, 10.51it/s, v_num=21, val_loss=0.110, val_map=0.324, train_loss=0.0685]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 37/37 [00:03<00:00, 10.38it/s, v_num=21, val_loss=0.110, val_map=0.324, train_loss=0.0685]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.11it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.10988053679466248    │
# │          val_map          │    0.3238782286643982     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.10988053679466248, 'val_map': 0.3238782286643982}]

# %% [markdown]
# ### Задание 3 (3 балла). Выбор anchors с помощью кластеризации
#
# В статье [YOLO9000: Better, Faster, Stronger](https://arxiv.org/abs/1612.08242) в разделе 2. Better. Dimension clusters описан способ выбора anchor boxes через кластеризацию обучающего датасета.
#
# Проделайте то же самое с вашим обучающим датасетом, чтобы выбрать несколько anchor boxes.
#
# В качестве результата выведите получившиеся размеры anchors для # Clusters = 5

# %%
# %pip install pyclustering
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyclustering in /home/jupyter/.local/lib/python3.10/site-packages (0.10.1.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pyclustering) (1.10.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pyclustering) (3.7.1)
# Requirement already satisfied: numpy>=1.15.2 in /usr/local/lib/python3.10/dist-packages (from pyclustering) (1.22.4)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from pyclustering) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->pyclustering) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->pyclustering) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pyclustering
from pyclustering.cluster.kmeans import kmeans
from pyclustering.utils.metric import type_metric, distance_metric
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer

# %%
class AnchorsDataset(Dataset):
    def __init__(
        self, subset_dir: Path, image_size: int = 256, grid_size: int = GRID_SIZE
    ) -> None:
        super().__init__()
        self.subset_dir = subset_dir
        self.items = list((self.subset_dir / "inputs").glob("*.pt"))
        # Ignore IoU threshold
        self.ignore_iou_thresh = 0.5
        self.grid_size = grid_size
        self.image_size = image_size

    def __len__(self) -> int:
        return len(self.items)

    def __getitem__(self, index: int) -> Tensor:
        boxes = torch.load(
            self.subset_dir / "bounding_boxes" / self.items[index].parts[-1], weights_only=True
        )
        boxes = box_convert(boxes, "xyxy", "cxcywh")
        return boxes

# %%
torch.manual_seed(42)

# %%
train_dataset = AnchorsDataset(Path("yeast_cell_in_microstructures_dataset/train"))
boxes = []
for i in range(len(train_dataset)):
    for j in range(len(train_dataset[i])):
        boxes.append([train_dataset[i][j][2], train_dataset[i][j][3]]) #нужна ширина и высота

# %%
def knn_dist(x, y):
    intersection =  min(x[0],y[0]) * min(x[1],y[1])
    union = x[0]*x[1] + y[0]*y[1] - intersection
    return 1 - intersection/union

# %%
manhattan_metric = distance_metric(type_metric.USER_DEFINED, func=knn_dist);
initial_centers = kmeans_plusplus_initializer(boxes, 5).initialize()
kmeans_ = kmeans(boxes, initial_centers, metric=manhattan_metric)

kmeans_.process()
clusters = kmeans_.get_clusters()
claster_anchors = [(int(w), int(h)) for w, h in kmeans_.get_centers()]
print(claster_anchors)
# Out:
# [(70, 105), (43, 47), (91, 88), (57, 84), (61, 61)]

# %%
rescaled_anchors = torch.tensor(claster_anchors, device = device) / IMAGE_SIZE * GRID_SIZE

# %%
trainer = L.Trainer(
    accelerator="auto",
    max_epochs=30,
    logger=TensorBoardLogger(save_dir="."),
)

lit_module = Lit(
    model=TinyYOLO(num_anchors=len(claster_anchors)), learning_rate=0.001
)
datamodule = YeastDetectionDataModule(image_size=256, anchors=claster_anchors, batch_size=BATCH_SIZE)
trainer.fit(model=lit_module, datamodule=datamodule,)
trainer.validate(model=lit_module, datamodule=datamodule,)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/utilities/parsing.py:208: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | TinyYOLO             | 116 K  | train
# 1 | map   | MeanAveragePrecision | 0      | train
# -------------------------------------------------------
# 116 K     Trainable params
# 0         Non-trainable params
# 116 K     Total params
# 0.467     Total estimated model params size (MB)
# 29        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/loops/fit_loop.py:298: The number of training batches (37) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|██████████| 37/37 [00:01<00:00, 19.68it/s, v_num=39]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.14it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.70it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.72it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.59it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.60it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.54it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.98it/s]
# Epoch 1: 100%|██████████| 37/37 [00:01<00:00, 19.90it/s, v_num=39, val_loss=0.297, val_map=0.132, train_loss=0.534]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.40it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.97it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.97it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.86it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.84it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.27it/s]
# Epoch 2: 100%|██████████| 37/37 [00:01<00:00, 19.82it/s, v_num=39, val_loss=0.179, val_map=0.227, train_loss=0.211]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.58it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  4.09it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.10it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  4.00it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.00it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.97it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.44it/s]
# Epoch 3: 100%|██████████| 37/37 [00:01<00:00, 20.09it/s, v_num=39, val_loss=0.151, val_map=0.276, train_loss=0.153]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.27it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.85it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.81it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.19it/s]
# Epoch 4: 100%|██████████| 37/37 [00:01<00:00, 19.92it/s, v_num=39, val_loss=0.166, val_map=0.203, train_loss=0.122]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.23it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.74it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.82it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.72it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.72it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.68it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.12it/s]
# Epoch 5: 100%|██████████| 37/37 [00:01<00:00, 20.16it/s, v_num=39, val_loss=0.114, val_map=0.353, train_loss=0.101]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#                                                                    /s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:02,  2.46it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:01<00:01,  2.82it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:01,  2.97it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.12it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.18it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.59it/s]
# Epoch 6: 100%|██████████| 37/37 [00:01<00:00, 19.83it/s, v_num=39, val_loss=0.115, val_map=0.384, train_loss=0.0814]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.24it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.74it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.19it/s]
# Epoch 7: 100%|██████████| 37/37 [00:01<00:00, 19.92it/s, v_num=39, val_loss=0.114, val_map=0.388, train_loss=0.0792]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.36it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.96it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.86it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.85it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.25it/s]
# Epoch 8: 100%|██████████| 37/37 [00:01<00:00, 19.75it/s, v_num=39, val_loss=0.115, val_map=0.385, train_loss=0.0759]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.38it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.96it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.85it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.85it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.81it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.27it/s]
# Epoch 9: 100%|██████████| 37/37 [00:01<00:00, 20.09it/s, v_num=39, val_loss=0.113, val_map=0.384, train_loss=0.0724]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.40it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.91it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.22it/s]
# Epoch 10: 100%|██████████| 37/37 [00:01<00:00, 19.41it/s, v_num=39, val_loss=0.112, val_map=0.389, train_loss=0.0702]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.31it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.18it/s]
# Epoch 11: 100%|██████████| 37/37 [00:01<00:00, 19.83it/s, v_num=39, val_loss=0.113, val_map=0.390, train_loss=0.0671]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.42it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.86it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.75it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 12: 100%|██████████| 37/37 [00:01<00:00, 19.97it/s, v_num=39, val_loss=0.114, val_map=0.386, train_loss=0.068]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.34it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.84it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.74it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.19it/s]
# Epoch 13: 100%|██████████| 37/37 [00:01<00:00, 19.76it/s, v_num=39, val_loss=0.114, val_map=0.389, train_loss=0.067]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.34it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.85it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.81it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.10it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.17it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.57it/s]
# Epoch 14: 100%|██████████| 37/37 [00:01<00:00, 19.61it/s, v_num=39, val_loss=0.114, val_map=0.390, train_loss=0.0677]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.36it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.82it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.89it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.75it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 15: 100%|██████████| 37/37 [00:01<00:00, 19.56it/s, v_num=39, val_loss=0.114, val_map=0.384, train_loss=0.066]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.43it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.74it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.19it/s]
# Epoch 16: 100%|██████████| 37/37 [00:01<00:00, 19.70it/s, v_num=39, val_loss=0.114, val_map=0.385, train_loss=0.066]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.27it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.72it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.16it/s]
# Epoch 17: 100%|██████████| 37/37 [00:01<00:00, 19.50it/s, v_num=39, val_loss=0.114, val_map=0.388, train_loss=0.0669]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.33it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.82it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.81it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.75it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 18: 100%|██████████| 37/37 [00:01<00:00, 19.88it/s, v_num=39, val_loss=0.115, val_map=0.383, train_loss=0.0667]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.36it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.74it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 19: 100%|██████████| 37/37 [00:01<00:00, 19.95it/s, v_num=39, val_loss=0.114, val_map=0.382, train_loss=0.0657]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.24it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.86it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.18it/s]
# Epoch 20: 100%|██████████| 37/37 [00:01<00:00, 20.06it/s, v_num=39, val_loss=0.114, val_map=0.383, train_loss=0.0657]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.31it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.89it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.80it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.21it/s]
# Epoch 21: 100%|██████████| 37/37 [00:01<00:00, 19.89it/s, v_num=39, val_loss=0.114, val_map=0.386, train_loss=0.0667]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.42it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.92it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.83it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.82it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.18it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.59it/s]
# Epoch 22: 100%|██████████| 37/37 [00:01<00:00, 19.83it/s, v_num=39, val_loss=0.116, val_map=0.386, train_loss=0.0662]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.36it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.90it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.18it/s]
# Epoch 23: 100%|██████████| 37/37 [00:01<00:00, 19.64it/s, v_num=39, val_loss=0.114, val_map=0.388, train_loss=0.0655]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.37it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.85it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.18it/s]
# Epoch 24: 100%|██████████| 37/37 [00:01<00:00, 19.89it/s, v_num=39, val_loss=0.113, val_map=0.386, train_loss=0.0658]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.27it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.86it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.72it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.17it/s]
# Epoch 25: 100%|██████████| 37/37 [00:01<00:00, 19.96it/s, v_num=39, val_loss=0.114, val_map=0.384, train_loss=0.0661]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.30it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.81it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.86it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.73it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.17it/s]
# Epoch 26: 100%|██████████| 37/37 [00:01<00:00, 19.85it/s, v_num=39, val_loss=0.114, val_map=0.386, train_loss=0.0657]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.30it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.83it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.89it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.82it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.82it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.21it/s]
# Epoch 27: 100%|██████████| 37/37 [00:01<00:00, 19.54it/s, v_num=39, val_loss=0.114, val_map=0.386, train_loss=0.0658]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.44it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.87it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.92it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.74it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 28: 100%|██████████| 37/37 [00:01<00:00, 19.99it/s, v_num=39, val_loss=0.114, val_map=0.386, train_loss=0.0662]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.36it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.84it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.91it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.79it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.75it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.20it/s]
# Epoch 29: 100%|██████████| 37/37 [00:01<00:00, 19.86it/s, v_num=39, val_loss=0.114, val_map=0.385, train_loss=0.0664]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.31it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.80it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:01,  3.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  3.76it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  3.77it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  3.72it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.17it/s]
# Epoch 29: 100%|██████████| 37/37 [00:04<00:00,  7.40it/s, v_num=39, val_loss=0.113, val_map=0.388, train_loss=0.0659]
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 29: 100%|██████████| 37/37 [00:05<00:00,  7.34it/s, v_num=39, val_loss=0.113, val_map=0.388, train_loss=0.0659]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/jupyter/.local/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.67it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.11313091218471527    │
# │          val_map          │    0.38776394724845886    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.11313091218471527, 'val_map': 0.38776394724845886}]

# %% [markdown]
# ### Задание 4 (4 балла + бонусы за лучшую точность). Обучите модель
#
#
# Ваша цель: $mAP > 0.6$ на валидации.
#
# Можете использовать весь арсенал:
# - использование множества якорных рамок (сформированных вручную или в результате кластеризации)
# - любые изменения функции ошибки
# - любые изменения архитектуры модели и регуляризация
# - аугментации (вспоминаем `torchvision.transforms` и `albumentations`)
# - любая длительность обучения, оптимизатор, расписание для learning rate
#
# Бонусы за повышенную точность:
# - **5 баллов**: $mAP > 0.65$
# - **1 балл** за каждые следующие $0.01$ (т. е. за $mAP > 0.72$ в этом задании вы получите $4 + 12 = 16$ баллов)
#
# **Важно**: перез запуском обучения зафиксируйте `torch.manual_seed()`

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#изменим функцию активации на tanh
class resCNNBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int, **kwargs):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels)
        self.activation = nn.tanh()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return self.activation(x)

class resTinyYOLO(nn.Module):
    def __init__(self, num_classes: int = 2, num_anchors: int = 1, in_channels: int = 1) -> None:
        super().__init__()
        self.num_classes = num_classes
        self.in_channels = in_channels
        self.num_anchors = num_anchors
        self.layers = nn.Sequential(
            CNNBlock(1, 16, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(16, 32, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(32, 64, kernel_size=3, stride=2, padding=1, dilation=2),
            CNNBlock(64, 128, kernel_size=3, stride=2, padding=1, groups=8),
            CNNBlock(128, 256, kernel_size=3, stride=1, padding=1, groups=8),
            CNNBlock(256, 512, kernel_size=3, stride=1, padding=1, groups=16),
            CNNBlock(512, 1024, kernel_size=3, stride=1, padding=1, groups=16),
            CNNBlock(1024, 1024, kernel_size=3, stride=1, padding=1, groups=32),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(1024, num_anchors * (num_classes + 5), kernel_size=1)
        )

    def forward(self, x: Tensor) -> Tensor:
        x = self.layers(x)
        B, _, W, H = x.shape
        x = x.view(B, self.num_anchors, self.num_classes + 5, W, H)  # B A F W H
        x = x.permute(0, 1, 3, 4, 2)  # B A W H F
        return x

# %%
torch.manual_seed(42)
trainer = L.Trainer(
    accelerator="auto",
    max_epochs=25,
    logger=TensorBoardLogger(save_dir="."),
)

lit_module = Lit(
    model=resTinyYOLO(num_anchors=len(claster_anchors)), learning_rate=0.003
)
datamodule = YeastDetectionDataModule(image_size=256, anchors=claster_anchors, batch_size=BATCH_SIZE)
trainer.fit(model=lit_module, datamodule=datamodule,)
trainer.validate(model=lit_module, datamodule=datamodule,)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | resTinyYOLO          | 774 K  | train
# 1 | map   | MeanAveragePrecision | 0      | train
# -------------------------------------------------------
# 774 K     Trainable params
# 0         Non-trainable params
# 774 K     Total params
# 3.099     Total estimated model params size (MB)
# 37        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 37/37 [00:05<00:00,  6.90it/s, v_num=140]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.25it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.86it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.02it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:00,  4.00it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.02it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.01it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.54it/s]
# Epoch 1: 100%|██████████| 37/37 [00:05<00:00,  6.91it/s, v_num=140, val_loss=0.264, val_map=0.202, train_loss=0.446]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.71it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  4.86it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.03it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.98it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  5.00it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.96it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.59it/s]
# Epoch 2: 100%|██████████| 37/37 [00:05<00:00,  6.97it/s, v_num=140, val_loss=0.202, val_map=0.376, train_loss=0.255]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.70it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.23it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.21it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.83it/s]
# Epoch 3: 100%|██████████| 37/37 [00:05<00:00,  6.98it/s, v_num=140, val_loss=0.224, val_map=0.393, train_loss=0.141]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  4.90it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  4.51it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.69it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.64it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.65it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.55it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.14it/s]
# Epoch 4: 100%|██████████| 37/37 [00:05<00:00,  6.63it/s, v_num=140, val_loss=0.169, val_map=0.413, train_loss=0.0853]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.43it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  4.88it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.09it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.02it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  5.00it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.91it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.51it/s]
# Epoch 5: 100%|██████████| 37/37 [00:05<00:00,  6.62it/s, v_num=140, val_loss=0.0855, val_map=0.460, train_loss=0.0573]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.73it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.23it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.98it/s]
# Epoch 6: 100%|██████████| 37/37 [00:05<00:00,  6.64it/s, v_num=140, val_loss=0.069, val_map=0.649, train_loss=0.0387]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.61it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.26it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.33it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  6.00it/s]
# Epoch 7: 100%|██████████| 37/37 [00:05<00:00,  6.57it/s, v_num=140, val_loss=0.0651, val_map=0.696, train_loss=0.0317]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.37it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.13it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.22it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.17it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.80it/s]
# Epoch 8: 100%|██████████| 37/37 [00:05<00:00,  6.58it/s, v_num=140, val_loss=0.0675, val_map=0.675, train_loss=0.0289]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.41it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.10it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.27it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.17it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.16it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.12it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.75it/s]
# Epoch 9: 100%|██████████| 37/37 [00:05<00:00,  6.66it/s, v_num=140, val_loss=0.066, val_map=0.683, train_loss=0.0257]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.63it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.27it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.21it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.82it/s]
# Epoch 10: 100%|██████████| 37/37 [00:05<00:00,  6.54it/s, v_num=140, val_loss=0.0655, val_map=0.688, train_loss=0.0231]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.40it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.11it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.26it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.19it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.15it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.79it/s]
# Epoch 11: 100%|██████████| 37/37 [00:05<00:00,  6.59it/s, v_num=140, val_loss=0.0662, val_map=0.691, train_loss=0.0219]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.68it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.01it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.28it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.23it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.85it/s]
# Epoch 12: 100%|██████████| 37/37 [00:05<00:00,  6.67it/s, v_num=140, val_loss=0.0666, val_map=0.693, train_loss=0.0215]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.66it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.22it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.28it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 13: 100%|██████████| 37/37 [00:05<00:00,  6.66it/s, v_num=140, val_loss=0.0662, val_map=0.695, train_loss=0.0208]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.87it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.29it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.23it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.17it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.19it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.15it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.77it/s]
# Epoch 14: 100%|██████████| 37/37 [00:05<00:00,  6.63it/s, v_num=140, val_loss=0.067, val_map=0.693, train_loss=0.0209]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.97it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.22it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.20it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# Epoch 15: 100%|██████████| 37/37 [00:05<00:00,  6.71it/s, v_num=140, val_loss=0.0664, val_map=0.692, train_loss=0.0207]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.97it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.48it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.35it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.26it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.91it/s]
# Epoch 16: 100%|██████████| 37/37 [00:05<00:00,  6.67it/s, v_num=140, val_loss=0.0663, val_map=0.696, train_loss=0.021]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  6.00it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.39it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.49it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.32it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.28it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 17: 100%|██████████| 37/37 [00:05<00:00,  6.67it/s, v_num=140, val_loss=0.0661, val_map=0.693, train_loss=0.0207]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.97it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.41it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.31it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.26it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.91it/s]
# Epoch 18: 100%|██████████| 37/37 [00:05<00:00,  6.64it/s, v_num=140, val_loss=0.0668, val_map=0.694, train_loss=0.0203]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.55it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.21it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.86it/s]
# Epoch 19: 100%|██████████| 37/37 [00:05<00:00,  6.63it/s, v_num=140, val_loss=0.0667, val_map=0.696, train_loss=0.0204]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.29it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.11it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.18it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.20it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.20it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# Epoch 20: 100%|██████████| 37/37 [00:05<00:00,  6.72it/s, v_num=140, val_loss=0.0668, val_map=0.694, train_loss=0.0205]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00,  6.03it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.37it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.46it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.28it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# Epoch 21: 100%|██████████| 37/37 [00:05<00:00,  6.70it/s, v_num=140, val_loss=0.0663, val_map=0.696, train_loss=0.0207]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.88it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.20it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.27it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.27it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.23it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.87it/s]
# Epoch 22: 100%|██████████| 37/37 [00:05<00:00,  6.62it/s, v_num=140, val_loss=0.0669, val_map=0.694, train_loss=0.0198]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.94it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.36it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.42it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.33it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.28it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.21it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.85it/s]
# Epoch 23: 100%|██████████| 37/37 [00:05<00:00,  6.52it/s, v_num=140, val_loss=0.0663, val_map=0.695, train_loss=0.0206]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.64it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.34it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.24it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.18it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.82it/s]
# Epoch 24: 100%|██████████| 37/37 [00:05<00:00,  6.49it/s, v_num=140, val_loss=0.0668, val_map=0.693, train_loss=0.021]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:01,  5.35it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.10it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.28it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.25it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.22it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  5.19it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# Epoch 24: 100%|██████████| 37/37 [00:07<00:00,  4.90it/s, v_num=140, val_loss=0.0666, val_map=0.696, train_loss=0.0205]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 37/37 [00:07<00:00,  4.82it/s, v_num=140, val_loss=0.0666, val_map=0.696, train_loss=0.0205]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.96it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         val_loss          │    0.06664577126502991    │
# │          val_map          │    0.6955863237380981     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.06664577126502991, 'val_map': 0.6955863237380981}]
